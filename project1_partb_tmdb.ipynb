# %% [markdown]
# ### Course: Foundation of Information
# ### Project 1 - Part B TMDB Problem
# ### Student: Muhammad Kamran Syed

# %% [markdown]
# ### Problem Statement:
#
# <p>
# A common business requirement in the context of information gathering is to extract and filter relevant
# data from web pages that host this information. However, access to information spread over several
# web pages, hosted potentially on multiple websites is a cumbersome process and we cannot rely on
# manual procedures to execute this task. In this project, you will employ a programmatic approach to
# access, parse and extract relevant information from a website of interest.
# </p>
#
# ### Objective:
#
# <p>
# The project's goal is to extract data (from a chosen number of pages) from The Movie Database website
# (https://www.themoviedb.org/) into a tabular data format so that further analysis (e.g., details about a
# movie's genre, cast, and user rating) can be facilitated.
# To execute this project, you will have to read the documentation links provided against each task in the
# assignment and adapt the code examples provided in the documentation for the task at hand
# </p>

# %% [markdown]
# ### 0. Preparation:
#
# Install the required libraries conditionally (if not already present), my own innovation :).

# %%
import subprocess
import sys

def pip_install_if_not_present(packageName, importName=None):
    """
    Install a package using pip if it's not already installed.

    :param packageName: The package name to install
    :param importName: In case import name is different than package name i.e. import bs4 from beautifulsoup4
    :retrun: True is package is already installed or correctly got installed. False otherwise
    """
    if importName is None:
        importName = packageName
    try:
        # Try to import the packages, if it is imported it is already installed
        __import__(importName)
        print(f"package [{packageName}] is already installed")
        return True
    except ImportError as e:
        print(f"package [{packageName}] is not installed: [{e}]")
    
    print(f"Installing package [{packageName}] now...")
    try:
        # run the pip install to install the package
        subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", packageName])
        # If installed correctly, it should be imported.
        __import__(importName)
    except subprocess.CalledProcessError as e:
        print(f"Error installing package [{packageName}]: {e}")
        return False
    except ImportError:
        print(f"Package [{packageName}] could not be imported after installation.")
        return False
    print(f"package [{packageName}] is installed")
    return True

# %%
if pip_install_if_not_present(packageName='requests'):
    None
if pip_install_if_not_present(packageName='beautifulsoup4', importName='bs4'):
    None
if pip_install_if_not_present(packageName='pandas'):
    None
# Out:
# package [requests] is already installed
# package [beautifulsoup4] is already installed
# package [pandas] is already installed

# %%
#For pretty printing, this is built in python standard library, no need to install
from pprint import pprint

# %% [markdown]
# ### 1. Establish a connection to webpage [TheMovieDb](https://www.themoviedb.org/movie)

# %%
# define some Constants, conventionally we represent Constants as all caps
# URL to scrape
URL = 'https://www.themoviedb.org/movie'

# User-Agent header to avoid 403 Forbidden error
# Since I am in MiddleEast region (KSA), hence specifying the expected response language to be English
# Otherwise, by default Arabic response (title description) would be returned
NEEDED_HEADERS = {
    'User-Agent':"Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36",
    'Accept-Language': "en-US,en;q=0.9"
}

# %% [markdown]
# ##### 1.a. Import requests library and formulate a get request to download the contents of the webpage:
# ("https://www.themoviedb.org/movie")

# %%
import requests

response = requests.get(url=URL, headers=NEEDED_HEADERS)
response
# Out:
# <Response [200]>

# %% [markdown]
# ##### 1.b. Verify the status code of the request and confirm that the request was executed appropriately

# %%
if response:
    if response.status_code == 200:
        print(f"Request was successfull with status code [{response.status_code}] to [{URL}]")
    else:
        print(f"Request failed with status code [{response.status_code}] to [{URL}]")
else:
    print(f"Request failed with no response from [{URL}]")
# Out:
# Request was successfull with status code [200] to [https://www.themoviedb.org/movie]

# %% [markdown]
# ##### 1.c. Print the contents of the page obtained from the response and save it in a variable

# %%
page_content = response.content
pprint(page_content)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en" class="no-js">\n  <head>\n    <title>Popul'
#  b'ar Movies &#8212; The Movie Database (TMDB)</title>\n    <meta http-equiv'
#  b'="cleartype" content="on">\n    <meta charset="utf-8">\n    <meta name="ke'
#  b'ywords" content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresse'
#  b's, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast">\n  '
#  b'  <meta name="mobile-web-app-capable" content="yes">\n    <meta name="app'
#  b'le-mobile-web-app-capable" content="yes">\n    <meta name="viewport" cont'
#  b'ent="width=device-width,initial-scale=1">\n      <meta name="description"'
#  b' content="The Movie Database (TMDB) is a popular, user editable database for'
#  b' movies and TV shows.">\n    <meta name="msapplication-TileImage" content'
#  b'="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f7'
#  b'5d26dab1224173a96fecc962.png">\n<meta name="msapplication-TileColor" cont'
#  b'ent="#032541">\n<meta name="theme-color" content="#032541">\n<link rel="ap'
#  b'ple-touch-icon" sizes="180x180" href="/assets/2/apple-touch-icon-57ed4b3b045'
#  b'0fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png">\n<link rel="i'
#  b'con" type="image/png" sizes="32x32" href="/assets/2/favicon-32x32-543a21832c'
#  b'8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png">\n<link rel="'
#  b'icon" type="image/png" sizes="16x16" href="/assets/2/favicon-16x16-b362d2678'
#  b'73ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png">\n<link rel='
#  b'"manifest" href="/manifest.json?version=3">\n    <link rel="canonical" hr'
#  b'ef="https://www.themoviedb.org/movie">\n    <link rel="search" type="appl'
#  b'ication/opensearchdescription+xml" title="TMDB Search" href="/opensearch.xml'
#  b'">\n    <link rel="preload" href="/assets/2/Consensus-3cba2c4d050ea63dbf7'
#  b'783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" as="font" type="font/wo'
#  b'ff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans-pr'
#  b'o-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regul'
#  b'ar-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" a'
#  b's="font" type="font/woff2" crossorigin>\n    <link rel="preload" href="/a'
#  b'ssets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyril'
#  b'lic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff5605'
#  b'71dddcb5542a.woff2" as="font" type="font/woff2" crossorigin>\n    <link r'
#  b'el="preload" href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_'
#  b'greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e883'
#  b'4bd20a7a1124c4c0a5a8f7892f3e99.woff2" as="font" type="font/woff2" crossorigi'
#  b'n>\n    <link rel="preload" href="/assets/2/source-sans-pro-v14-vietnames'
#  b'e_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7'
#  b'b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" as="font" type="font'
#  b'/woff2" crossorigin>\n    <link rel="preload" href="/assets/2/source-sans'
#  b'-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-70'
#  b'0-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" as'
#  b'="font" type="font/woff2" crossorigin>\n    <link rel="stylesheet" href="'
#  b'/assets/2/v4/fonts-dcbded27193f5556450c516bf4b553e851bc6d1c8d1c8e6da45a57e3f'
#  b'c278cff.css" media="screen">\n    <link rel="stylesheet" href="/assets/2/'
#  b'application-6f8fac3fb42c8f97248a06d21a821ae926df35a7a4319bda760a8fd95e36dd59'
#  b'.css" media="screen">\n    \n      <link rel="stylesheet" href="/assets/2/'
#  b'v4/media-d65a112740c7f410033fc1a950402d9cf9753aad44666b98c63db5a6fe7b5416.cs'
#  b's" media="screen">\n      \n      <link rel="stylesheet" href="/assets/2/v'
#  b'4/discover-b2c3bb76e3d2b2323e842dc4be56a342c51e08c3bb91c6a010e8b401b180f117.'
#  b'css" media="screen">\n      \n      <link rel="stylesheet" href="/assets/2'
#  b'/v4/account-cce66521478d16895d1c5e31e821f696433bada2fdee3fc3f9876fac529aa3c7'
#  b'.css" media="screen">\n      \n    <link rel="alternate" hreflang="x-defau'
#  b'lt" href="https://www.themoviedb.org/movie">\n    <link rel="alternate" h'
#  b'reflang="af-ZA" href="https://www.themoviedb.org/movie?language=af-ZA">\n'
#  b'    <link rel="alternate" hreflang="ar-SA" href="https://www.themoviedb.org/'
#  b'movie?language=ar-SA">\n    <link rel="alternate" hreflang="be-BY" href="'
#  b'https://www.themoviedb.org/movie?language=be-BY">\n    <link rel="alterna'
#  b'te" hreflang="bg-BG" href="https://www.themoviedb.org/movie?language=bg-BG">'
#  b'\n    <link rel="alternate" hreflang="bn-BD" href="https://www.themoviedb'
#  b'.org/movie?language=bn-BD">\n    <link rel="alternate" hreflang="br-FR" h'
#  b'ref="https://www.themoviedb.org/movie?language=br-FR">\n    <link rel="al'
#  b'ternate" hreflang="ca-ES" href="https://www.themoviedb.org/movie?language=ca'
#  b'-ES">\n    <link rel="alternate" hreflang="ch-GU" href="https://www.themo'
#  b'viedb.org/movie?language=ch-GU">\n    <link rel="alternate" hreflang="cs-'
#  b'CZ" href="https://www.themoviedb.org/movie?language=cs-CZ">\n    <link re'
#  b'l="alternate" hreflang="cy-GB" href="https://www.themoviedb.org/movie?langua'
#  b'ge=cy-GB">\n    <link rel="alternate" hreflang="da-DK" href="https://www.'
#  b'themoviedb.org/movie?language=da-DK">\n    <link rel="alternate" hreflang'
#  b'="de-DE" href="https://www.themoviedb.org/movie?language=de-DE">\n    <li'
#  b'nk rel="alternate" hreflang="el-GR" href="https://www.themoviedb.org/movie?l'
#  b'anguage=el-GR">\n    <link rel="alternate" hreflang="en-US" href="https:/'
#  b'/www.themoviedb.org/movie?language=en-US">\n    <link rel="alternate" hre'
#  b'flang="eo-EO" href="https://www.themoviedb.org/movie?language=eo-EO">\n  '
#  b'  <link rel="alternate" hreflang="es-ES" href="https://www.themoviedb.org/mo'
#  b'vie?language=es-ES">\n    <link rel="alternate" hreflang="et-EE" href="ht'
#  b'tps://www.themoviedb.org/movie?language=et-EE">\n    <link rel="alternate'
#  b'" hreflang="eu-ES" href="https://www.themoviedb.org/movie?language=eu-ES'
#  b'">\n    <link rel="alternate" hreflang="fa-IR" href="https://www.themovie'
#  b'db.org/movie?language=fa-IR">\n    <link rel="alternate" hreflang="fi-FI"'
#  b' href="https://www.themoviedb.org/movie?language=fi-FI">\n    <link rel="'
#  b'alternate" hreflang="fr-FR" href="https://www.themoviedb.org/movie?language='
#  b'fr-FR">\n    <link rel="alternate" hreflang="ga-IE" href="https://www.the'
#  b'moviedb.org/movie?language=ga-IE">\n    <link rel="alternate" hreflang="g'
#  b'd-GB" href="https://www.themoviedb.org/movie?language=gd-GB">\n    <link '
#  b'rel="alternate" hreflang="gl-ES" href="https://www.themoviedb.org/movie?lang'
#  b'uage=gl-ES">\n    <link rel="alternate" hreflang="he-IL" href="https://ww'
#  b'w.themoviedb.org/movie?language=he-IL">\n    <link rel="alternate" hrefla'
#  b'ng="hi-IN" href="https://www.themoviedb.org/movie?language=hi-IN">\n    <'
#  b'link rel="alternate" hreflang="hr-HR" href="https://www.themoviedb.org/movie'
#  b'?language=hr-HR">\n    <link rel="alternate" hreflang="hu-HU" href="https'
#  b'://www.themoviedb.org/movie?language=hu-HU">\n    <link rel="alternate" h'
#  b'reflang="id-ID" href="https://www.themoviedb.org/movie?language=id-ID">\n'
#  b'    <link rel="alternate" hreflang="it-IT" href="https://www.themoviedb.org/'
#  b'movie?language=it-IT">\n    <link rel="alternate" hreflang="ja-JP" href="'
#  b'https://www.themoviedb.org/movie?language=ja-JP">\n    <link rel="alterna'
#  b'te" hreflang="ka-GE" href="https://www.themoviedb.org/movie?language=ka-GE">'
#  b'\n    <link rel="alternate" hreflang="kk-KZ" href="https://www.themoviedb'
#  b'.org/movie?language=kk-KZ">\n    <link rel="alternate" hreflang="kn-IN" h'
#  b'ref="https://www.themoviedb.org/movie?language=kn-IN">\n    <link rel="al'
#  b'ternate" hreflang="ko-KR" href="https://www.themoviedb.org/movie?language=ko'
#  b'-KR">\n    <link rel="alternate" hreflang="ku-TR" href="https://www.themo'
#  b'viedb.org/movie?language=ku-TR">\n    <link rel="alternate" hreflang="ky-'
#  b'KG" href="https://www.themoviedb.org/movie?language=ky-KG">\n    <link re'
#  b'l="alternate" hreflang="lt-LT" href="https://www.themoviedb.org/movie?langua'
#  b'ge=lt-LT">\n    <link rel="alternate" hreflang="lv-LV" href="https://www.'
#  b'themoviedb.org/movie?language=lv-LV">\n    <link rel="alternate" hreflang'
#  b'="ml-IN" href="https://www.themoviedb.org/movie?language=ml-IN">\n    <li'
#  b'nk rel="alternate" hreflang="mr-IN" href="https://www.themoviedb.org/movie?l'
#  b'anguage=mr-IN">\n    <link rel="alternate" hreflang="ms-MY" href="https:/'
#  b'/www.themoviedb.org/movie?language=ms-MY">\n    <link rel="alternate" hre'
#  b'flang="nb-NO" href="https://www.themoviedb.org/movie?language=nb-NO">\n  '
#  b'  <link rel="alternate" hreflang="nl-NL" href="https://www.themoviedb.org/mo'
#  b'vie?language=nl-NL">\n    <link rel="alternate" hreflang="no-NO" href="ht'
#  b'tps://www.themoviedb.org/movie?language=no-NO">\n    <link rel="alternate'
#  b'" hreflang="pa-IN" href="https://www.themoviedb.org/movie?language=pa-IN'
#  b'">\n    <link rel="alternate" hreflang="pl-PL" href="https://www.themovie'
#  b'db.org/movie?language=pl-PL">\n    <link rel="alternate" hreflang="pt-PT"'
#  b' href="https://www.themoviedb.org/movie?language=pt-PT">\n    <link rel="'
#  b'alternate" hreflang="ro-RO" href="https://www.themoviedb.org/movie?language='
#  b'ro-RO">\n    <link rel="alternate" hreflang="ru-RU" href="https://www.the'
#  b'moviedb.org/movie?language=ru-RU">\n    <link rel="alternate" hreflang="s'
#  b'i-LK" href="https://www.themoviedb.org/movie?language=si-LK">\n    <link '
#  b'rel="alternate" hreflang="sk-SK" href="https://www.themoviedb.org/movie?lang'
#  b'uage=sk-SK">\n    <link rel="alternate" hreflang="sl-SI" href="https://ww'
#  b'w.themoviedb.org/movie?language=sl-SI">\n    <link rel="alternate" hrefla'
#  b'ng="so-SO" href="https://www.themoviedb.org/movie?language=so-SO">\n    <'
#  b'link rel="alternate" hreflang="sq-AL" href="https://www.themoviedb.org/movie'
#  b'?language=sq-AL">\n    <link rel="alternate" hreflang="sr-RS" href="https'
#  b'://www.themoviedb.org/movie?language=sr-RS">\n    <link rel="alternate" h'
#  b'reflang="sv-SE" href="https://www.themoviedb.org/movie?language=sv-SE">\n'
#  b'    <link rel="alternate" hreflang="sw-TZ" href="https://www.themoviedb.org/'
#  b'movie?language=sw-TZ">\n    <link rel="alternate" hreflang="ta-IN" href="'
#  b'https://www.themoviedb.org/movie?language=ta-IN">\n    <link rel="alterna'
#  b'te" hreflang="te-IN" href="https://www.themoviedb.org/movie?language=te-IN">'
#  b'\n    <link rel="alternate" hreflang="tl-PH" href="https://www.themoviedb'
#  b'.org/movie?language=tl-PH">\n    <link rel="alternate" hreflang="th-TH" h'
#  b'ref="https://www.themoviedb.org/movie?language=th-TH">\n    <link rel="al'
#  b'ternate" hreflang="tr-TR" href="https://www.themoviedb.org/movie?language=tr'
#  b'-TR">\n    <link rel="alternate" hreflang="uk-UA" href="https://www.themo'
#  b'viedb.org/movie?language=uk-UA">\n    <link rel="alternate" hreflang="ur-'
#  b'PK" href="https://www.themoviedb.org/movie?language=ur-PK">\n    <link re'
#  b'l="alternate" hreflang="uz-UZ" href="https://www.themoviedb.org/movie?langua'
#  b'ge=uz-UZ">\n    <link rel="alternate" hreflang="vi-VN" href="https://www.'
#  b'themoviedb.org/movie?language=vi-VN">\n    <link rel="alternate" hreflang'
#  b'="zh-CN" href="https://www.themoviedb.org/movie?language=zh-CN">\n    <li'
#  b'nk rel="alternate" hreflang="zu-ZA" href="https://www.themoviedb.org/movie?l'
#  b'anguage=zu-ZA">\n    <link rel="alternate" hreflang="ar-AE" href="https:/'
#  b'/www.themoviedb.org/movie?language=ar-AE">\n    <link rel="alternate" hre'
#  b'flang="ar-BH" href="https://www.themoviedb.org/movie?language=ar-BH">\n  '
#  b'  <link rel="alternate" hreflang="ar-EG" href="https://www.themoviedb.org/mo'
#  b'vie?language=ar-EG">\n    <link rel="alternate" hreflang="ar-IQ" href="ht'
#  b'tps://www.themoviedb.org/movie?language=ar-IQ">\n    <link rel="alternate'
#  b'" hreflang="ar-JO" href="https://www.themoviedb.org/movie?language=ar-JO'
#  b'">\n    <link rel="alternate" hreflang="ar-LY" href="https://www.themovie'
#  b'db.org/movie?language=ar-LY">\n    <link rel="alternate" hreflang="ar-MA"'
#  b' href="https://www.themoviedb.org/movie?language=ar-MA">\n    <link rel="'
#  b'alternate" hreflang="ar-QA" href="https://www.themoviedb.org/movie?language='
#  b'ar-QA">\n    <link rel="alternate" hreflang="ar-YE" href="https://www.the'
#  b'moviedb.org/movie?language=ar-YE">\n    <link rel="alternate" hreflang="a'
#  b'r-TD" href="https://www.themoviedb.org/movie?language=ar-TD">\n    <link '
#  b'rel="alternate" hreflang="ca-AD" href="https://www.themoviedb.org/movie?lang'
#  b'uage=ca-AD">\n    <link rel="alternate" hreflang="de-AT" href="https://ww'
#  b'w.themoviedb.org/movie?language=de-AT">\n    <link rel="alternate" hrefla'
#  b'ng="de-CH" href="https://www.themoviedb.org/movie?language=de-CH">\n    <'
#  b'link rel="alternate" hreflang="el-CY" href="https://www.themoviedb.org/movie'
#  b'?language=el-CY">\n    <link rel="alternate" hreflang="en-AG" href="https'
#  b'://www.themoviedb.org/movie?language=en-AG">\n    <link rel="alternate" h'
#  b'reflang="en-AU" href="https://www.themoviedb.org/movie?language=en-AU">\n'
#  b'    <link rel="alternate" hreflang="en-BB" href="https://www.themoviedb.org/'
#  b'movie?language=en-BB">\n    <link rel="alternate" hreflang="en-BZ" href="'
#  b'https://www.themoviedb.org/movie?language=en-BZ">\n    <link rel="alterna'
#  b'te" hreflang="en-CA" href="https://www.themoviedb.org/movie?language=en-CA">'
#  b'\n    <link rel="alternate" hreflang="en-CM" href="https://www.themoviedb'
#  b'.org/movie?language=en-CM">\n    <link rel="alternate" hreflang="en-GB" h'
#  b'ref="https://www.themoviedb.org/movie?language=en-GB">\n    <link rel="al'
#  b'ternate" hreflang="en-GG" href="https://www.themoviedb.org/movie?language=en'
#  b'-GG">\n    <link rel="alternate" hreflang="en-GH" href="https://www.themo'
#  b'viedb.org/movie?language=en-GH">\n    <link rel="alternate" hreflang="en-'
#  b'GI" href="https://www.themoviedb.org/movie?language=en-GI">\n    <link re'
#  b'l="alternate" hreflang="en-GY" href="https://www.themoviedb.org/movie?langua'
#  b'ge=en-GY">\n    <link rel="alternate" hreflang="en-IE" href="https://www.'
#  b'themoviedb.org/movie?language=en-IE">\n    <link rel="alternate" hreflang'
#  b'="en-JM" href="https://www.themoviedb.org/movie?language=en-JM">\n    <li'
#  b'nk rel="alternate" hreflang="en-KE" href="https://www.themoviedb.org/movie?l'
#  b'anguage=en-KE">\n    <link rel="alternate" hreflang="en-LC" href="https:/'
#  b'/www.themoviedb.org/movie?language=en-LC">\n    <link rel="alternate" hre'
#  b'flang="en-MW" href="https://www.themoviedb.org/movie?language=en-MW">\n  '
#  b'  <link rel="alternate" hreflang="en-NZ" href="https://www.themoviedb.org/mo'
#  b'vie?language=en-NZ">\n    <link rel="alternate" hreflang="en-PG" href="ht'
#  b'tps://www.themoviedb.org/movie?language=en-PG">\n    <link rel="alternate'
#  b'" hreflang="en-TC" href="https://www.themoviedb.org/movie?language=en-TC'
#  b'">\n    <link rel="alternate" hreflang="en-ZM" href="https://www.themovie'
#  b'db.org/movie?language=en-ZM">\n    <link rel="alternate" hreflang="en-ZW"'
#  b' href="https://www.themoviedb.org/movie?language=en-ZW">\n    <link rel="'
#  b'alternate" hreflang="es-AR" href="https://www.themoviedb.org/movie?language='
#  b'es-AR">\n    <link rel="alternate" hreflang="es-CL" href="https://www.the'
#  b'moviedb.org/movie?language=es-CL">\n    <link rel="alternate" hreflang="e'
#  b's-DO" href="https://www.themoviedb.org/movie?language=es-DO">\n    <link '
#  b'rel="alternate" hreflang="es-EC" href="https://www.themoviedb.org/movie?lang'
#  b'uage=es-EC">\n    <link rel="alternate" hreflang="es-GT" href="https://ww'
#  b'w.themoviedb.org/movie?language=es-GT">\n    <link rel="alternate" hrefla'
#  b'ng="es-GQ" href="https://www.themoviedb.org/movie?language=es-GQ">\n    <'
#  b'link rel="alternate" hreflang="es-HN" href="https://www.themoviedb.org/movie'
#  b'?language=es-HN">\n    <link rel="alternate" hreflang="es-MX" href="https'
#  b'://www.themoviedb.org/movie?language=es-MX">\n    <link rel="alternate" h'
#  b'reflang="es-NI" href="https://www.themoviedb.org/movie?language=es-NI">\n'
#  b'    <link rel="alternate" hreflang="es-PA" href="https://www.themoviedb.org/'
#  b'movie?language=es-PA">\n    <link rel="alternate" hreflang="es-PE" href="'
#  b'https://www.themoviedb.org/movie?language=es-PE">\n    <link rel="alterna'
#  b'te" hreflang="es-PY" href="https://www.themoviedb.org/movie?language=es-PY">'
#  b'\n    <link rel="alternate" hreflang="es-SV" href="https://www.themoviedb'
#  b'.org/movie?language=es-SV">\n    <link rel="alternate" hreflang="es-UY" h'
#  b'ref="https://www.themoviedb.org/movie?language=es-UY">\n    <link rel="al'
#  b'ternate" hreflang="fr-BF" href="https://www.themoviedb.org/movie?language=fr'
#  b'-BF">\n    <link rel="alternate" hreflang="fr-CA" href="https://www.themo'
#  b'viedb.org/movie?language=fr-CA">\n    <link rel="alternate" hreflang="fr-'
#  b'CD" href="https://www.themoviedb.org/movie?language=fr-CD">\n    <link re'
#  b'l="alternate" hreflang="fr-CI" href="https://www.themoviedb.org/movie?langua'
#  b'ge=fr-CI">\n    <link rel="alternate" hreflang="fr-GF" href="https://www.'
#  b'themoviedb.org/movie?language=fr-GF">\n    <link rel="alternate" hreflang'
#  b'="fr-GP" href="https://www.themoviedb.org/movie?language=fr-GP">\n    <li'
#  b'nk rel="alternate" hreflang="fr-MC" href="https://www.themoviedb.org/movie?l'
#  b'anguage=fr-MC">\n    <link rel="alternate" hreflang="fr-ML" href="https:/'
#  b'/www.themoviedb.org/movie?language=fr-ML">\n    <link rel="alternate" hre'
#  b'flang="fr-MU" href="https://www.themoviedb.org/movie?language=fr-MU">\n  '
#  b'  <link rel="alternate" hreflang="fr-PF" href="https://www.themoviedb.org/mo'
#  b'vie?language=fr-PF">\n    <link rel="alternate" hreflang="it-VA" href="ht'
#  b'tps://www.themoviedb.org/movie?language=it-VA">\n    <link rel="alternate'
#  b'" hreflang="ms-SG" href="https://www.themoviedb.org/movie?language=ms-SG'
#  b'">\n    <link rel="alternate" hreflang="nl-BE" href="https://www.themovie'
#  b'db.org/movie?language=nl-BE">\n    <link rel="alternate" hreflang="pt-AO"'
#  b' href="https://www.themoviedb.org/movie?language=pt-AO">\n    <link rel="'
#  b'alternate" hreflang="pt-BR" href="https://www.themoviedb.org/movie?language='
#  b'pt-BR">\n    <link rel="alternate" hreflang="pt-MZ" href="https://www.the'
#  b'moviedb.org/movie?language=pt-MZ">\n    <link rel="alternate" hreflang="r'
#  b'o-MD" href="https://www.themoviedb.org/movie?language=ro-MD">\n    <link '
#  b'rel="alternate" hreflang="sr-ME" href="https://www.themoviedb.org/movie?lang'
#  b'uage=sr-ME">\n    <link rel="alternate" hreflang="sq-XK" href="https://ww'
#  b'w.themoviedb.org/movie?language=sq-XK">\n    <link rel="alternate" hrefla'
#  b'ng="zh-HK" href="https://www.themoviedb.org/movie?language=zh-HK">\n    <'
#  b'link rel="alternate" hreflang="zh-SG" href="https://www.themoviedb.org/movie'
#  b'?language=zh-SG">\n    <link rel="alternate" hreflang="zh-TW" href="https'
#  b'://www.themoviedb.org/movie?language=zh-TW">\n\n      <script src="https:/'
#  b'/cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" char'
#  b'set="UTF-8" data-domain-script="23223fbb-5c84-48df-836d-0a83fb7b2c03"></scri'
#  b'pt>\n      <script>function OptanonWrapper() {}</script>\n    <script src='
#  b'"/assets/2/lozad.min-7f803337d01a657607bca6b20e06f371c3895b36a5f2be03a8fa9b5'
#  b'e16c9a83e.js"></script>\n    <script src="/assets/2/jquery-3.6.0.min-ff15'
#  b'23fb7389539c84c65aba19260648793bb4f5e29329d2ee8804bc37a3fe6e.js"></scrip'
#  b't>\n    <script src="/assets/2/kendo-93daa31ab3dcca8723478255a3b3c3f0a9e6'
#  b'672dddc612e114391786423c1870.js"></script>\n      <script src="/assets/2/'
#  b'kendo-2021.1.204/cultures/kendo.culture.en-US.min-61ce5636474a35333ecff74fe3'
#  b'0c528d459bcee29b3b32fc0c58ac77de788b34.js"></script>\n      <script src="'
#  b'/assets/2/kendo-2021.1.204/messages/kendo.messages.en-US.min-79da68ae0221b4f'
#  b'd7978805d0c79cc7f682fddace5f2137aa0dae8fe1c5ddacd.js"></script>\n    <scr'
#  b'ipt src="/assets/2/application-365501d0f2bb3e2b4dceec07a6fd380428faba303d1e8'
#  b'0e2a0b837edfd5a2c57.js"></script>\n    <script src="/assets/2/pusher.min-'
#  b'ee61b1e19799dd5aae92a3d91bc970e6147c6fe4395eacf3e499ed1451650f22.js"></scrip'
#  b't>\n      <script src="/assets/2/application.desktop-ea69249141a43ef7c6a5'
#  b'9a19ee40eface5e171cf03eefffddb488574a66dea02.js" defer></script>\n      <'
#  b'script src="/assets/2/kendo-2021.1.204/kendo.calendar.min-ff597f14a778b702ec'
#  b'1cf9967dec754e429caf1558c8b89f0de036e8efe39761.js" defer></script>\n     '
#  b' <script src="/assets/2/kendo-2021.1.204/kendo.datepicker.min-9efa21cba90055'
#  b'5da428262129f44042706c5abac5644c872d9cac78f010493a.js" defer></script>\n '
#  b'     <script src="/assets/2/kendo-2021.1.204/kendo.slider.min-1e770b8fc7facf'
#  b'8ee48d3b0ad7abdfb598ab17cb69add240accc8df5fa2bc919.js" defer></script>\n '
#  b'   <script>\n      window.mobileDevice = false;\n      detected_timezone ='
#  b' Intl.DateTimeFormat().resolvedOptions().timeZone;\n        timezone = de'
#  b'tected_timezone;\n      kendo.culture("en-US");\n    </script>\n      <scri'
#  b"pt>\n        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n "
#  b"       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)"
#  b"[0],\n        j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=t"
#  b"rue;j.src=\n        'https://www.googletagmanager.com/gtm.js?id='+i+dl;f."
#  b"parentNode.insertBefore(j,f);\n        })(window,document,'script','dataL"
#  b'ayer\',\'GTM-5QWVXV\');\n      </script>\n  </head>\n  <body class="en v4"'
#  b'>\n    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id'
#  b'=GTM-5QWVXV" height="0" width="0" style="display:none;visibility:hidden"></i'
#  b'frame></noscript>\n\n\n    <div class="page_wrap movie_wrap">\n\n\n\n<heade'
#  b'r class="normal smaller no_animation smaller  subtle">\n  <div class="con'
#  b'tent">\n    <div class="sub_media">\n      <div class="nav_wrapper">\n     '
#  b'     <a class="logo" href="/" aria-label="Home">\n            <img src="/'
#  b'assets/2/v4/logos/v2/blue_short-8e7b30f73a4020692ccca9c88bafe5dcb6f8a62a4c6b'
#  b'c55cd9ba82bb2cd95f6c.svg" alt="The Movie Database (TMDB)" width="154" height'
#  b'="20">\n          </a>\n\n        <ul class="dropdown_menu navigation prima'
#  b'ry">\n            <li>\n              <a class="no_click" href="/movie" ar'
#  b'ia-label="Movies">Movies</a>\n\n              <ul>\n                <li><a '
#  b'href="/movie" aria-label="Popular">Popular</a></li>\n                <li>'
#  b'<a href="/movie/now-playing" aria-label="Now Playing">Now Playing</a></l'
#  b'i>\n                <li><a href="/movie/upcoming" aria-label="Upcoming">U'
#  b'pcoming</a></li>\n                <li><a href="/movie/top-rated" aria-lab'
#  b'el="Top Rated">Top Rated</a></li>\n              </ul>\n            </li>\n'
#  b'            <li>\n              <a  class="no_click" href="/tv" aria-labe'
#  b'l="TV Shows">TV Shows</a>\n\n              <ul>\n                <li><a hre'
#  b'f="/tv" aria-label="Popular">Popular</a></li>\n                <li><a hre'
#  b'f="/tv/airing-today" aria-label="Airing Today">Airing Today</a></li>\n   '
#  b'             <li><a href="/tv/on-the-air" aria-label="On TV">On TV</a></'
#  b'li>\n                <li><a href="/tv/top-rated" aria-label="Top Rated">T'
#  b'op Rated</a></li>\n              </ul>\n            </li>\n            <li>'
#  b'\n              <a class="no_click" href="/person" aria-label="People">Pe'
#  b'ople</a>\n\n              <ul>\n                <li><a href="/person" aria-'
#  b'label="Popular People">Popular People</a></li>\n              </ul>\n     '
#  b'       </li>\n            <li>\n              <a class="no_click" href="#"'
#  b' aria-label="More">More</a>\n\n              <ul>\n                <li><a h'
#  b'ref="/discuss" aria-label="Discussions">Discussions</a></li>\n           '
#  b'     <li><a href="/leaderboard" aria-label="Leaderboard">Leaderboard</a></li'
#  b'>\n                <li><a href="/talk" aria-label="Support">Support</a></'
#  b'li>\n                  <li><a href="https://developer.themoviedb.org/docs'
#  b'" target="_blank" aria-label="API">API</a></li>\n              </ul>\n    '
#  b'        </li>\n        </ul>\n      </div>\n\n        <div class="flex">'
#  b'\n          <ul class="primary">\n            <li class="glyph new_buttons'
#  b'">\n              <a class="new_icon no_click" href="#" aria-label="Creat'
#  b'e New Movie or TV Show">\n                <span class="glyphicons_v2 plus'
#  b' white"></span>\n              </a>\n            </li>\n            <li cla'
#  b'ss="translate">\n              <div>en</div>\n            </li>\n          '
#  b'    <li><a href="/login" aria-label="Login">Login</a></li>\n             '
#  b' <li><a href="/signup" aria-label="Join TMDB">Join TMDB</a></li>\n\n      '
#  b'      <li class="glyph search_buttons">\n              <a class="search" '
#  b'href="/search" aria-label="Search"><span class="glyphicons_v2 search blue"><'
#  b'/span></a>\n              <a class="close hide" href="/search" aria-label'
#  b'="Search"><span class="glyphicons_v2 menu-close invert svg"></span></a>\n'
#  b'            </li>\n          </ul>\n        </div>\n    </div>\n  </div>'
#  b'\n  <div class="search_bar hide">\n    <section class="search show_search_'
#  b'false">\n      <div class="sub_media">\n        <form id="search_form" act'
#  b'ion="/search" method="get" accept-charset="utf-8">\n          <label>\n   '
#  b'         <input dir="auto" id="search_v4" name="query" type="text" autocorre'
#  b'ct="off" autofill="off" autocomplete="off" spellcheck="false" placeholder="S'
#  b'earch for a movie, tv show, person..." value="">\n          </label>\n    '
#  b'      <input type="submit" disabled>\n        </form>\n      </div>\n    </'
#  b'section>\n  </div>\n</header>\n\n\n<main id="main" class="smaller  subtle'
#  b' show_search_false">\n\n  <section class="inner_content">\n  <div id="media'
#  b'_v4" class="media discover">\n    <div class="column_wrapper">\n      <div'
#  b' class="content_wrapper">\n        <div class="title">\n          <h2>Popu'
#  b'lar Movies</h2>\n        </div>\n\n        <div class="content">\n          '
#  b'<div class="">\n\n              <div class="filter_panel card closed">\n   '
#  b'             <div class="name">\n                  <h2>Sort</h2>\n        '
#  b'          <span class="glyphicons_v2 chevron-right"></span>\n            '
#  b'    </div>\n\n                <div class="filter">\n                  <h3>S'
#  b'ort Results By</h3>\n                  <select id="sort_by" name="sort_by'
#  b'" class="kendo_dropdown full_width font_size_1">\n                    <op'
#  b'tion value="popularity.desc" selected>Popularity Descending</option>\n   '
#  b'                 <option value="popularity.asc">Popularity Ascending</option'
#  b'>\n                    <option value="vote_average.desc">Rating Descendin'
#  b'g</option>\n                    <option value="vote_average.asc">Rating A'
#  b'scending</option>\n                    <option value="primary_release_dat'
#  b'e.desc">Release Date Descending</option>\n                    <option val'
#  b'ue="primary_release_date.asc">Release Date Ascending</option>\n          '
#  b'          <option value="title.asc">Title (A-Z)</option>\n               '
#  b'     <option value="title.desc">Title (Z-A)</option>\n                  <'
#  b'/select>\n                </div>\n              </div>\n\n              <div'
#  b' class="filter_panel card closed">\n                <div class="name">\n  '
#  b'                <h2>Where To Watch <span>33</span></h2>\n                '
#  b'  <span class="glyphicons_v2 chevron-right"></span>\n                </di'
#  b'v>\n\n                <div class="filter">\n                  <h3>My Servic'
#  b'es <span class="tooltip glyphicons_v2 circle-question" data-tooltip-id="#ott'
#  b'_tooltip"></span></h3>\n                  <label class="k-form-field">\n  '
#  b'                  <input id="my_services" class="k-checkbox" type="checkbox"'
#  b' name="my_services" value="true" disabled>\n                    <label fo'
#  b'r="my_services" class="k-checkbox-label">Restrict searches to my subscribed '
#  b'services?</label>\n                  </label>\n                </div>\n\n   '
#  b'             <div class="filter">\n                  <h3>Country</h3>\n   '
#  b'               <div id="watch_region" class="font_size_1 kendo_dropdown" sty'
#  b'le="width: 100%;"></div>\n\n                  <span id="ott_provider_wrapp'
#  b'er">\n                    <ul id="ott_providers" class="ott_providers mul'
#  b'ti_select image">\n    <li data-value="8" class="">\n  <a class="no_click"'
#  b' href="#" title="Netflix">\n    <img src="https://media.themoviedb.org/t/'
#  b'p/original/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg" width="50" height="50" alt="Netf'
#  b'lix">\n    <div><span class="glyphicons_v2 check white"></span></div>\n  <'
#  b'/a>\n</li>\n\n    <li data-value="2" class="">\n  <a class="no_click" href="'
#  b'#" title="Apple TV">\n    <img src="https://media.themoviedb.org/t/p/orig'
#  b'inal/9ghgSC0MA082EL6HLCW3GalykFD.jpg" width="50" height="50" alt="Apple TV">'
#  b'\n    <div><span class="glyphicons_v2 check white"></span></div>\n  </a>\n<'
#  b'/li>\n\n    <li data-value="350" class="">\n  <a class="no_click" href="#" '
#  b'title="Apple TV Plus">\n    <img src="https://media.themoviedb.org/t/p/or'
#  b'iginal/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg" width="50" height="50" alt="Apple TV'
#  b' Plus">\n    <div><span class="glyphicons_v2 check white"></span></div>\n '
#  b' </a>\n</li>\n\n    <li data-value="3" class="">\n  <a class="no_click" href'
#  b'="#" title="Google Play Movies">\n    <img src="https://media.themoviedb.'
#  b'org/t/p/original/8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg" width="50" height="50" alt'
#  b'="Google Play Movies">\n    <div><span class="glyphicons_v2 check white">'
#  b'</span></div>\n  </a>\n</li>\n\n    <li data-value="393" class="">\n  <a '
#  b'class="no_click" href="#" title="FlixOl\xc3\xa9">\n    <img src="https://me'
#  b'dia.themoviedb.org/t/p/original/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg" width="50" '
#  b'height="50" alt="FlixOl\xc3\xa9">\n    <div><span class="glyphicons_v2 chec'
#  b'k white"></span></div>\n  </a>\n</li>\n\n    <li data-value="11" class="'
#  b'">\n  <a class="no_click" href="#" title="MUBI">\n    <img src="https://me'
#  b'dia.themoviedb.org/t/p/original/fj9Y8iIMFUC6952HwxbGixTQPb7.jpg" width="50" '
#  b'height="50" alt="MUBI">\n    <div><span class="glyphicons_v2 check white"'
#  b'></span></div>\n  </a>\n</li>\n\n    <li data-value="232" class="">\n  <a'
#  b' class="no_click" href="#" title="Zee5">\n    <img src="https://media.the'
#  b'moviedb.org/t/p/original/vPIW5b0ebTLj9bFCZypoBbF8wSl.jpg" width="50" height='
#  b'"50" alt="Zee5">\n    <div><span class="glyphicons_v2 check white"></span'
#  b'></div>\n  </a>\n</li>\n\n    <li data-value="511" class="">\n  <a class='
#  b'"no_click" href="#" title="iWantTFC">\n    <img src="https://media.themov'
#  b'iedb.org/t/p/original/nHxedyutqerk1yWBsc17mF8gteZ.jpg" width="50" height="50'
#  b'" alt="iWantTFC">\n    <div><span class="glyphicons_v2 check white"></spa'
#  b'n></div>\n  </a>\n</li>\n\n    <li data-value="190" class="">\n  <a class'
#  b'="no_click" href="#" title="Curiosity Stream">\n    <img src="https://med'
#  b'ia.themoviedb.org/t/p/original/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg" width="50" h'
#  b'eight="50" alt="Curiosity Stream">\n    <div><span class="glyphicons_v2 c'
#  b'heck white"></span></div>\n  </a>\n</li>\n\n    <li data-value="309" class="'
#  b'">\n  <a class="no_click" href="#" title="Sun Nxt">\n    <img src="https:/'
#  b'/media.themoviedb.org/t/p/original/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg" width="5'
#  b'0" height="50" alt="Sun Nxt">\n    <div><span class="glyphicons_v2 check '
#  b'white"></span></div>\n  </a>\n</li>\n\n    <li data-value="521" class=""'
#  b'>\n  <a class="no_click" href="#" title="Spamflix">\n    <img src="https:/'
#  b'/media.themoviedb.org/t/p/original/k2YgZyxij5RcnS1qqUYEUrJB4oQ.jpg" width="5'
#  b'0" height="50" alt="Spamflix">\n    <div><span class="glyphicons_v2 check'
#  b' white"></span></div>\n  </a>\n</li>\n\n    <li data-value="534" class="'
#  b'">\n  <a class="no_click" href="#" title="Argo">\n    <img src="https://me'
#  b'dia.themoviedb.org/t/p/original/jQMOpRluniNQSEp6V7IvtKxXMW.jpg" width="50" h'
#  b'eight="50" alt="Argo">\n    <div><span class="glyphicons_v2 check white">'
#  b'</span></div>\n  </a>\n</li>\n\n    <li data-value="551" class="">\n  <a '
#  b'class="no_click" href="#" title="Magellan TV">\n    <img src="https://med'
#  b'ia.themoviedb.org/t/p/original/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg" width="50" h'
#  b'eight="50" alt="Magellan TV">\n    <div><span class="glyphicons_v2 check '
#  b'white"></span></div>\n  </a>\n</li>\n\n    <li data-value="554" class=""'
#  b'>\n  <a class="no_click" href="#" title="BroadwayHD">\n    <img src="https'
#  b'://media.themoviedb.org/t/p/original/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg" width='
#  b'"50" height="50" alt="BroadwayHD">\n    <div><span class="glyphicons_v2 c'
#  b'heck white"></span></div>\n  </a>\n</li>\n\n    <li data-value="532" class="'
#  b'">\n  <a class="no_click" href="#" title="aha">\n    <img src="https://med'
#  b'ia.themoviedb.org/t/p/original/8WerMI8XcZXqPpkHTZNtzMzousF.jpg" width="50" h'
#  b'eight="50" alt="aha">\n    <div><span class="glyphicons_v2 check white"><'
#  b'/span></div>\n  </a>\n</li>\n\n    <li data-value="559" class="">\n  <a c'
#  b'lass="no_click" href="#" title="Filmzie">\n    <img src="https://media.th'
#  b'emoviedb.org/t/p/original/eUBxtrqO26wAJfYOZJOzhQEo3mm.jpg" width="50" height'
#  b'="50" alt="Filmzie">\n    <div><span class="glyphicons_v2 check white"></'
#  b'span></div>\n  </a>\n</li>\n\n    <li data-value="567" class="">\n  <a cl'
#  b'ass="no_click" href="#" title="True Story">\n    <img src="https://media.'
#  b'themoviedb.org/t/p/original/aRPDQvVcpeY07sjI6lAALMCL0ti.jpg" width="50" heig'
#  b'ht="50" alt="True Story">\n    <div><span class="glyphicons_v2 check whit'
#  b'e"></span></div>\n  </a>\n</li>\n\n    <li data-value="569" class="">\n  '
#  b'<a class="no_click" href="#" title="DocAlliance Films">\n    <img src="ht'
#  b'tps://media.themoviedb.org/t/p/original/vbXJBJVv3u3YWt6ml0l0ldDblXT.jpg" wid'
#  b'th="50" height="50" alt="DocAlliance Films">\n    <div><span class="glyph'
#  b'icons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="31'
#  b'5" class="">\n  <a class="no_click" href="#" title="Hoichoi">\n    <img sr'
#  b'c="https://media.themoviedb.org/t/p/original/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg'
#  b'" width="50" height="50" alt="Hoichoi">\n    <div><span class="glyphicons'
#  b'_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="344" cl'
#  b'ass="">\n  <a class="no_click" href="#" title="Rakuten Viki">\n    <img sr'
#  b'c="https://media.themoviedb.org/t/p/original/5L2bwr9DhUg28oSMEPRCNwB2y7B.jpg'
#  b'" width="50" height="50" alt="Rakuten Viki">\n    <div><span class="glyph'
#  b'icons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="44'
#  b'5" class="">\n  <a class="no_click" href="#" title="Classix">\n    <img sr'
#  b'c="https://media.themoviedb.org/t/p/original/uFjAjvrKMII0H766QzyHDNkZdKX.jpg'
#  b'" width="50" height="50" alt="Classix">\n    <div><span class="glyphicons'
#  b'_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="629" cl'
#  b'ass="">\n  <a class="no_click" href="#" title="OSN">\n    <img src="https:'
#  b'//media.themoviedb.org/t/p/original/kC6JTo59Gj6I4vJPyBAYGh0sKAE.jpg" width="'
#  b'50" height="50" alt="OSN">\n    <div><span class="glyphicons_v2 check whi'
#  b'te"></span></div>\n  </a>\n</li>\n\n    <li data-value="630" class="">\n '
#  b' <a class="no_click" href="#" title="STARZPLAY">\n    <img src="https://m'
#  b'edia.themoviedb.org/t/p/original/pDroY6RxYdVw63eAepag4b116Ub.jpg" width="50"'
#  b' height="50" alt="STARZPLAY">\n    <div><span class="glyphicons_v2 check '
#  b'white"></span></div>\n  </a>\n</li>\n\n    <li data-value="581" class=""'
#  b'>\n  <a class="no_click" href="#" title="iQIYI">\n    <img src="https://me'
#  b'dia.themoviedb.org/t/p/original/c4eVkfMna2VzHzZ8N2vWXUnMrlD.jpg" width="50" '
#  b'height="50" alt="iQIYI">\n    <div><span class="glyphicons_v2 check white'
#  b'"></span></div>\n  </a>\n</li>\n\n    <li data-value="119" class="">\n  <'
#  b'a class="no_click" href="#" title="Amazon Prime Video">\n    <img src="ht'
#  b'tps://media.themoviedb.org/t/p/original/dQeAar5H991VYporEjUspolDarG.jpg" wid'
#  b'th="50" height="50" alt="Amazon Prime Video">\n    <div><span class="glyp'
#  b'hicons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="6'
#  b'77" class="">\n  <a class="no_click" href="#" title="Eventive">\n    <img '
#  b'src="https://media.themoviedb.org/t/p/original/fwx5Ed64TkfWiRH1SOSkc4781Ts.j'
#  b'pg" width="50" height="50" alt="Eventive">\n    <div><span class="glyphic'
#  b'ons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="692"'
#  b' class="">\n  <a class="no_click" href="#" title="Cultpix">\n    <img src='
#  b'"https://media.themoviedb.org/t/p/original/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg" '
#  b'width="50" height="50" alt="Cultpix">\n    <div><span class="glyphicons_v'
#  b'2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-value="701" clas'
#  b's="">\n  <a class="no_click" href="#" title="FilmBox+">\n    <img src="htt'
#  b'ps://media.themoviedb.org/t/p/original/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg" widt'
#  b'h="50" height="50" alt="FilmBox+">\n    <div><span class="glyphicons_v2 c'
#  b'heck white"></span></div>\n  </a>\n</li>\n\n    <li data-value="638" class="'
#  b'">\n  <a class="no_click" href="#" title="Public Domain Movies">\n    <img'
#  b' src="https://media.themoviedb.org/t/p/original/aN0Y2BNZQBH91JkVOeLTs8IhQrH.'
#  b'jpg" width="50" height="50" alt="Public Domain Movies">\n    <div><span c'
#  b'lass="glyphicons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li dat'
#  b'a-value="1715" class="">\n  <a class="no_click" href="#" title="Shahid VI'
#  b'P">\n    <img src="https://media.themoviedb.org/t/p/original/7qZED0kLBtiV'
#  b'8mLRNBtW4PQCAqW.jpg" width="50" height="50" alt="Shahid VIP">\n    <div><'
#  b'span class="glyphicons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <'
#  b'li data-value="1750" class="">\n  <a class="no_click" href="#" title="TOD'
#  b'">\n    <img src="https://media.themoviedb.org/t/p/original/bFxDjHDXP02u1'
#  b'dLPZfTsTC1L6EA.jpg" width="50" height="50" alt="TOD">\n    <div><span cla'
#  b'ss="glyphicons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-'
#  b'value="1771" class="">\n  <a class="no_click" href="#" title="Takflix">\n '
#  b'   <img src="https://media.themoviedb.org/t/p/original/ed0vz5bryWIhQB5sHiuGv'
#  b'HKnHHn.jpg" width="50" height="50" alt="Takflix">\n    <div><span class="'
#  b'glyphicons_v2 check white"></span></div>\n  </a>\n</li>\n\n    <li data-valu'
#  b'e="1958" class="">\n  <a class="no_click" href="#" title="AD tv">\n    <im'
#  b'g src="https://media.themoviedb.org/t/p/original/mK8nfCXfwoAa6cAkHUSKCkLEIKK'
#  b'.jpg" width="50" height="50" alt="AD tv">\n    <div><span class="glyphico'
#  b'ns_v2 check white"></span></div>\n  </a>\n</li>\n\n</ul>\n\n              '
#  b'    </span>\n                </div>\n              </div>\n\n            <di'
#  b'v class="filter_panel card">\n              <div class="name" data-callba'
#  b'ck="filterCallback()">\n                <h2>Filters</h2>\n                '
#  b'<span class="glyphicons_v2 chevron-right"></span>\n              </div>\n\n'
#  b'              <div class="filter">\n                <h3>Show Me<span clas'
#  b's="tooltip glyphicons_v2 circle-question" data-tooltip-id="#show_me_tooltip"'
#  b' ></span></h3>\n\n                <label class="k-form-field">\n           '
#  b'       <input id="show_me_everything" class="k-radio" type="radio" name="sho'
#  b'w_me" value="everything" checked="checked">\n                  <label for'
#  b'="show_me_everything" class="k-radio-label">Everything</label>\n         '
#  b'       </label>\n\n                <label class="k-form-field">\n          '
#  b'        <input id="show_me_not_seen" class="k-radio" type="radio" value="unw'
#  b'atched" name="show_me" disabled>\n                  <label for="show_me_n'
#  b'ot_seen" class="k-radio-label">Movies I Haven\'t Seen</label>\n           '
#  b'     </label>\n\n                <label class="k-form-field">\n            '
#  b'      <input id="show_me_seen" class="k-radio" type="radio" value="watched" '
#  b'name="show_me" disabled>\n                  <label for="show_me_seen" cla'
#  b'ss="k-radio-label">Movies I Have Seen</label>\n                </label>\n '
#  b'             </div>\n\n                <div class="filter">\n              '
#  b'    <h3>Availabilities</h3>\n\n                  <label class="k-form-fiel'
#  b'd">\n                    <input id="all_availabilities" class="k-checkbox'
#  b'" type="checkbox" name="all_availabilities" value="true" checked>\n      '
#  b'              <label for="all_availabilities" class="k-checkbox-label">Searc'
#  b'h all availabilities?</label>\n                  </label>\n\n              '
#  b'    <div id="availabilities_wrapper" class="labels hide">\n              '
#  b'        <label class="k-form-field">\n                        <input id="'
#  b'ott_monetization_type_flatrate" class="k-checkbox" type="checkbox" name="ott'
#  b'_monetization_type" value="flatrate" checked>\n                        <l'
#  b'abel for="ott_monetization_type_flatrate" class="k-checkbox-label">Stream</l'
#  b'abel>\n                      </label>\n                      <label class='
#  b'"k-form-field">\n                        <input id="ott_monetization_type'
#  b'_free" class="k-checkbox" type="checkbox" name="ott_monetization_type" value'
#  b'="free" checked>\n                        <label for="ott_monetization_ty'
#  b'pe_free" class="k-checkbox-label">Free</label>\n                      </l'
#  b'abel>\n                      <label class="k-form-field">\n               '
#  b'         <input id="ott_monetization_type_ads" class="k-checkbox" type="chec'
#  b'kbox" name="ott_monetization_type" value="ads" checked>\n                '
#  b'        <label for="ott_monetization_type_ads" class="k-checkbox-label">Ads<'
#  b'/label>\n                      </label>\n                      <label clas'
#  b's="k-form-field">\n                        <input id="ott_monetization_ty'
#  b'pe_rent" class="k-checkbox" type="checkbox" name="ott_monetization_type" val'
#  b'ue="rent" checked>\n                        <label for="ott_monetization_'
#  b'type_rent" class="k-checkbox-label">Rent</label>\n                      <'
#  b'/label>\n                      <label class="k-form-field">\n             '
#  b'           <input id="ott_monetization_type_buy" class="k-checkbox" type="ch'
#  b'eckbox" name="ott_monetization_type" value="buy" checked>\n              '
#  b'          <label for="ott_monetization_type_buy" class="k-checkbox-label">Bu'
#  b'y</label>\n                      </label>\n                  </div>\n      '
#  b'          </div>\n\n              <div class="filter">\n                  <'
#  b'h3>Release Dates</h3>\n\n                  <label class="k-form-field">\n  '
#  b'                  <input id="all_releases" class="k-checkbox" type="checkbox'
#  b'" name="all_releases" value="true" checked>\n                    <label f'
#  b'or="all_releases" class="k-checkbox-label">Search all releases?</label>\n'
#  b'                  </label>\n\n                  <div id="release_type_wrap'
#  b'per" class="labels hide">\n                    <label class="k-form-field'
#  b'" style="padding-bottom: 20px;">\n                      <input id="all_re'
#  b'lease_countries" class="k-checkbox" type="checkbox" name="all_release_countr'
#  b'ies" value="true" checked>\n                      <label for="all_release'
#  b'_countries" class="k-checkbox-label">Search all countries?</label>\n     '
#  b'               </label>\n                    <div id="search_all_countrie'
#  b's" class="hide">\n                      <input name="release_region" id="'
#  b'release_region" class="font_size_1 kendo_dropdown" style="width: 100%; margi'
#  b'n-bottom: 10px;" value="SA|XX">\n                    </div>\n\n            '
#  b'          <label class="k-form-field">\n                        <input id'
#  b'="release_type_2" class="k-checkbox" type="checkbox" name="release_type" val'
#  b'ue="2" checked>\n                        <label for="release_type_2" clas'
#  b's="k-checkbox-label">Theatrical (limited)</label>\n                      '
#  b'</label>\n                      <label class="k-form-field">\n            '
#  b'            <input id="release_type_3" class="k-checkbox" type="checkbox" na'
#  b'me="release_type" value="3" checked>\n                        <label for='
#  b'"release_type_3" class="k-checkbox-label">Theatrical</label>\n           '
#  b'           </label>\n                      <label class="k-form-field">\n '
#  b'                       <input id="release_type_1" class="k-checkbox" type="c'
#  b'heckbox" name="release_type" value="1" checked>\n                        '
#  b'<label for="release_type_1" class="k-checkbox-label">Premiere</label>\n  '
#  b'                    </label>\n                      <label class="k-form-'
#  b'field">\n                        <input id="release_type_4" class="k-chec'
#  b'kbox" type="checkbox" name="release_type" value="4" checked>\n           '
#  b'             <label for="release_type_4" class="k-checkbox-label">Digital</l'
#  b'abel>\n                      </label>\n                      <label class='
#  b'"k-form-field">\n                        <input id="release_type_5" class'
#  b'="k-checkbox" type="checkbox" name="release_type" value="5" checked>\n   '
#  b'                     <label for="release_type_5" class="k-checkbox-label">Ph'
#  b'ysical</label>\n                      </label>\n                      <lab'
#  b'el class="k-form-field">\n                        <input id="release_type'
#  b'_6" class="k-checkbox" type="checkbox" name="release_type" value="6" checked'
#  b'>\n                        <label for="release_type_6" class="k-checkbox-'
#  b'label">TV</label>\n                      </label>\n                  </div'
#  b'>\n\n                  <div class="year_column">\n                    <span'
#  b' class="col_1 font_size_1">from</span>\n                    <input id="re'
#  b'lease_date_gte" class="font_size_1" value="" style="width: 100%">\n      '
#  b'            </div>\n\n                  <div class="year_column">\n        '
#  b'            <span class="col_1 font_size_1">to</span>\n                  '
#  b'  <input id="release_date_lte" class="font_size_1" value="2025-02-19" style='
#  b'"width: 100%">\n                  </div>\n              </div>\n\n          '
#  b'    <div class="filter">\n                <h3>Genres</h3>\n               '
#  b' <ul id="with_genres" class="multi_select text" name="with_genres[]">\n  '
#  b'                  <li data-value="28"><a class="no_click" href="/discover/mo'
#  b'vie?with_genres=28">Action</a></li>\n                    <li data-value="'
#  b'12"><a class="no_click" href="/discover/movie?with_genres=12">Adventure</a><'
#  b'/li>\n                    <li data-value="16"><a class="no_click" href="/'
#  b'discover/movie?with_genres=16">Animation</a></li>\n                    <l'
#  b'i data-value="35"><a class="no_click" href="/discover/movie?with_genres=35">'
#  b'Comedy</a></li>\n                    <li data-value="80"><a class="no_cli'
#  b'ck" href="/discover/movie?with_genres=80">Crime</a></li>\n               '
#  b'     <li data-value="99"><a class="no_click" href="/discover/movie?with_genr'
#  b'es=99">Documentary</a></li>\n                    <li data-value="18"><a c'
#  b'lass="no_click" href="/discover/movie?with_genres=18">Drama</a></li>\n   '
#  b'                 <li data-value="10751"><a class="no_click" href="/discover/'
#  b'movie?with_genres=10751">Family</a></li>\n                    <li data-va'
#  b'lue="14"><a class="no_click" href="/discover/movie?with_genres=14">Fantasy</'
#  b'a></li>\n                    <li data-value="36"><a class="no_click" href'
# ...
#  b'    }).data("kendoAutoComplete");\n\n        $(\'#search_v4\').keydown(funct'
#  b'ion(event) {\n          if (event.keyCode == 13) {\n            if (proces'
#  b'sing_selected_item) {\n              return;\n            } else {\n       '
#  b'       processSelectedItem(null);\n            }\n          }\n        });\n'
#  b"\n        $('header #search_form').submit(function() {\n          return f"
#  b"alse;\n        });\n\n        var autocompleteInput = $('section.search .k-"
#  b"autocomplete input');\n        autocompleteInput.on('focus', function (e)"
#  b' {\n          var value = autocompleteInput.val();\n          if (value =='
#  b' null || value == \'\') {\n            $("#search_v4").data("kendoAutoCompl'
#  b'ete").search(\'\');\n          } else {\n            var fieldLength = value'
#  b'.length;\n            autocompleteInput[0].setSelectionRange(fieldLength,'
#  b" fieldLength);\n          }\n        });\n\n        $('li.search_buttons a.s"
#  b"earch').on('click', function(e) {\n          e.preventDefault();\n        "
#  b"  showSearch(true);\n        });\n\n        $('li.search_buttons a.close')."
#  b"on('click', function(e) {\n          e.preventDefault();\n          showSe"
#  b"arch(false);\n        });\n\n        $('main.show_search_false').on('click'"
#  b", function(e) {\n          showSearch(false);\n        });\n\n        $('hea"
#  b'der span.k-i-close[title="clear"]\').on(\'click\', function(e) {\n          '
#  b'$(\'#search_v4\').data("kendoAutoComplete").focus();\n        });\n\n\n   '
#  b"     public_media_type_map = { 'movie': 'Movie', 'tv': 'TV Show', 'person': "
#  b"'Person' };\n\n\n        $(document).on('keydown', null, 'b', function() {\n"
#  b"          if ( $('a.keyboard_s.parent').length ) {\n            $('a.keyb"
#  b"oard_s.parent')[0].click();\n          }\n        });\n\n        $(document)"
#  b".on('keyup', null, 's', function() {\n          if ( $('#search_v4').leng"
#  b'th ) {\n            showSearch(true);\n          }\n        });\n\n      '
#  b"  $(document).on('keyup', null, 'shift+/', function() {\n          keyboa"
#  b"rd_shortcut_popup.open();\n        });\n\n        $(document).on('keydown',"
#  b" null, 'left', function() {\n          if ( $('span.previous a.keyboard_s"
#  b"').length ) {\n            $('span.previous a.keyboard_s')[0].click();\n  "
#  b"        }\n        });\n\n        $(document).on('keydown', null, 'right', "
#  b"function() {\n          if ( $('span.next a.keyboard_s').length ) {\n     "
#  b"       $('span.next a.keyboard_s')[0].click();\n          }\n        });\n\n"
#  b"        $(document).on('keydown', null, 'm', function() {\n          if ("
#  b' $(\'#new_shortcut_bar\').length ) {\n            $("#new_shortcut_bar").fo'
#  b'cus();\n          }\n        });\n      });\n\n      var gender_lookup = '
#  b"{\n        0: 'two',\n        1: 'one',\n        2: 'two',\n        3: 'two'"
#  b'\n      }\n    </script>\n\n    <script id="person_template" type="text/x-ke'
#  b'ndo-tmpl">\n      <div class="item profile list_item grid_item">\n        '
#  b'<div class="image_content profile">\n          <a class="result" href="${'
#  b'data.url}" title="${data.name}" alt="${data.name}">\n            # if (da'
#  b'ta.profile_path) { #\n              <img class="" src="https://media.them'
#  b'oviedb.org/t/p/w66_and_h66_face${data.profile_path}" alt="${data.name}" widt'
#  b'h="45" height="45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face'
#  b'${data.profile_path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face'
#  b'${data.profile_path} 2x">\n            # } else { #\n              <div cl'
#  b'ass="glyphicons_v2 picture profile ${gender_lookup[data.gender]} grey no_ima'
#  b'ge_holder w45_and_h45"></div>\n            # } #\n          </a>\n        <'
#  b'/div>\n\n        <div class="content">\n          <p class="name"><a class='
#  b'"result" href="${data.url}" title="${data.name}" alt="${data.name}">${data.n'
#  b'ame}</a></p>\n\n          # if (data.known_for) { #\n            <p class="'
#  b'sub">${data.known_for}</p>\n          # } #\n        </div>\n      </div>\n '
#  b'   </script>\n\n    <script id="person_template_with_known_for" type="text'
#  b'/x-kendo-tmpl">\n      <div class="item profile list_item known_for">\n   '
#  b'     <div class="image_content profile">\n          # if (data.profile_pa'
#  b'th) { #\n            <img class="" src="https://media.themoviedb.org/t/p/'
#  b'w66_and_h66_face${data.profile_path}" alt="${data.name}" width="45" height="'
#  b'45" srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_'
#  b'path} 1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_'
#  b'path} 2x">\n          # } else { #\n            <div class="glyphicons_v2 '
#  b'picture grey no_image_holder w45_and_h45 profile"></div>\n          # } #'
#  b'\n        </div>\n\n        <div class="content">\n          <p class="name"'
#  b'>${data.name}</p>\n          # if (data.known_for) { #\n            <p cla'
#  b'ss="sub">${data.known_for_department} &bull; ${data.known_for}</p>\n     '
#  b'     # } else { #\n            <p class="sub">No known credits.</p>\n     '
#  b'     # } #\n        </div>\n      </div>\n    </script>\n\n    <script id'
#  b'="person_result_template" type="text/x-kendo-tmpl">\n      <div class="ac'
#  b'_item profile list_item known_for">\n        <div class="image_content pr'
#  b'ofile">\n          # if (data.profile_path) { #\n            <img class=""'
#  b' src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}"'
#  b' alt="${data.name}" width="45" height="45" srcset="https://media.themoviedb.'
#  b'org/t/p/w66_and_h66_face${data.profile_path} 1x, https://media.themoviedb.or'
#  b'g/t/p/w132_and_h132_bestv2${data.profile_path} 2x">\n          # } else {'
#  b' #\n            <div class="glyphicons_v2 picture grey no_image_holder w4'
#  b'5_and_h45 profile"></div>\n          # } #\n        </div>\n\n        <div c'
#  b'lass="content">\n          <p class="name">${data.name}</p>\n          # i'
#  b'f (data.known_for) { #\n            <p class="sub">\n              # if (d'
#  b'ata.media_type) { #\n                <span class="media_type person">#= p'
#  b'ublic_media_type_map[data.media_type] # &bull; </span>\n              # }'
#  b' #\n              # for (var i = 0; i < data.known_for.length; i++) { #\n '
#  b'             <span class="comma">#= data.known_for[i].title ? data.known_for'
#  b'[i].title : data.known_for[i].name #</span>\n              # } #\n        '
#  b'    </p>\n          # } else { #\n            <p class="sub">No known cred'
#  b'its.</p>\n          # } #\n        </div>\n      </div>\n    </script>\n\n'
#  b'    <script id="movie_result_template" type="text/x-kendo-tmpl">\n      <'
#  b'div class="ac_results">\n        <div class="ac_item poster list_item">\n '
#  b'         <div class="image_content poster">\n            # if (data.poste'
#  b'r_path) { #\n              <img class="" src="https://media.themoviedb.or'
#  b'g/t/p/w45_and_h67_bestv2${data.poster_path}" alt="${data.title}" width="45" '
#  b'height="67" srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${dat'
#  b'a.poster_path} 1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${dat'
#  b'a.poster_path} 2x">\n            # } else { #\n              <div class="g'
#  b'lyphicons_v2 picture grey no_image_holder w45_and_h67"></div>\n          '
#  b'  # } #\n          </div>\n\n          <div class="content">\n            <p'
#  b' class="name">${data.title}</p>\n            <p class="sub">\n            '
#  b'  # if (data.media_type) { #\n                <span class="media_type mov'
#  b'ie">#= public_media_type_map[data.media_type] # &bull; </span>\n         '
#  b'     # } #\n              # if (data.original_title !== data.title) { #\n '
#  b'               <span class="comma"><span class="original_title">#= data.orig'
#  b'inal_title #</span></span>\n              # } #\n              # if (data.'
#  b'release_date) { #\n                <span class="comma"><span class="relea'
#  b'se_date">#= data.release_date #</span></span>\n              # } #\n      '
#  b'      </p>\n          </div>\n        </div>\n      </div>\n    </script'
#  b'>\n\n    <script id="tv_show_result_template" type="text/x-kendo-tmpl">\n  '
#  b'    <div class="ac_item poster list_item">\n        <div class="image_con'
#  b'tent poster">\n          # if (data.poster_path) { #\n            <img cla'
#  b'ss="" src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_'
#  b'path}" alt="${data.title}" width="45" height="67" srcset="https://media.them'
#  b'oviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themo'
#  b'viedb.org/t/p/w90_and_h134_bestv2${data.poster_path} 2x">\n          # } '
#  b'else { #\n            <div class="glyphicons_v2 picture grey no_image_hol'
#  b'der w45_and_h67"></div>\n          # } #\n        </div>\n\n        <div cla'
#  b'ss="content">\n          <p class="name">${data.name}</p>\n          <p cl'
#  b'ass="sub">\n            # if (data.media_type) { #\n                <span '
#  b'class="media_type tv">#= public_media_type_map[data.media_type] # &bull; </s'
#  b'pan>\n              # } #\n            # if (data.original_name !== data.n'
#  b'ame) { #\n              <span class="comma"><span class="original_title">'
#  b'#= data.original_name #</span></span>\n            # } #\n            # if'
#  b' (data.first_air_date) { #\n              <span class="comma"><span class'
#  b'="release_date">#= data.first_air_date #</span></span>\n            # } #'
#  b'\n          </p>\n        </div>\n      </div>\n    </script>\n\n    <scri'
#  b'pt id="slim_movie_result_template" type="text/x-kendo-tmpl">\n      <div '
#  b'class="ac_item poster list_item">\n        <div class="image_content post'
#  b'er">\n          # if (data.poster_path) { #\n            <img class="" src'
#  b'="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" al'
#  b't="${data.title}" width="45" height="67" srcset="https://media.themoviedb.or'
#  b'g/t/p/w45_and_h67_bestv2${data.poster_path} 1x, https://media.themoviedb.org'
#  b'/t/p/w90_and_h134_bestv2${data.poster_path} 2x">\n          # } else { #\n'
#  b'            <div class="glyphicons_v2 picture grey no_image_holder w45_and_h'
#  b'67"></div>\n          # } #\n        </div>\n\n        <div class="content">'
#  b'\n          <p class="name">${data.title}</p>\n          <p class="sub">\n '
#  b'           # if (data.original_title !== data.title) { #\n              <'
#  b'span class="comma"><span class="original_title">#= data.original_title #</sp'
#  b'an></span>\n            # } #\n            # if (data.release_date) { #\n  '
#  b'            <span class="comma"><span class="release_date">#= data.release_d'
#  b'ate #</span></span>\n            # } #\n          </p>\n        </div>\n'
#  b'\n        <p><span class="media_type movie">#= public_media_type_map[data'
#  b'.media_type] #</span></p>\n      </div>\n    </script>\n\n    <script id="mu'
#  b'lti_search_template" type="text/x-kendo-tmpl">\n      <div class="ac_resu'
#  b'lts">\n        # if (data.media_type == \'movie\') { #\n          #= kendo.r'
#  b'ender(kendo.template($("\\\\#movie_result_template").html()), [data]) #\n  '
#  b"      # } else if (data.media_type == 'tv') { #\n          #= kendo.rende"
#  b'r(kendo.template($("\\\\#tv_show_result_template").html()), [data]) #\n    '
#  b"    # } else if (data.media_type == 'person') { #\n          #= kendo.ren"
#  b'der(kendo.template($("\\\\#person_result_template").html()), [data]) #\n   '
#  b'     # } #\n      </div>\n    </script>\n\n    <script id="search_v4_headerT'
#  b'emplate" type="text/x-kendo-template">\n      <div id="trending_search_he'
#  b'ader_template" class="slim_search_results_header">\n        <div class="w'
#  b'rapper">\n          <h2><span class="glyphicons_v2 trending"></span> Tren'
#  b'ding</h2>\n        </div>\n      </div>\n    </script>\n\n    <script id='
#  b'"search_no_data_template" type="text/x-kendo-template">\n      <div class'
#  b'="slim_search_results_header no_data">\n        <div class="wrapper">\n   '
#  b'       <h2>No Results</h2>\n        </div>\n      </div>\n    </script>'
#  b'\n\n    <script id="slim_multi_search_template" type="text/x-kendo-tmpl">\n'
#  b'      # if (data.media_type == \'movie\') { #\n        <div class="slim_sea'
#  b'rch_results slim">\n          <div class="wrapper">\n            <div clas'
#  b's="glyphicons_v2 film"></div>\n            <p>#= data.name # <span>in Mov'
#  b'ies</span></p>\n          </div>\n        </div>\n      # } else if (data.m'
#  b'edia_type == \'tv\') { #\n        <div class="slim_search_results slim">\n  '
#  b'        <div class="wrapper">\n            <div class="glyphicons_v2 tv">'
#  b'</div>\n            <p>#= data.name # <span>in TV Shows</span></p>\n      '
#  b"    </div>\n        </div>\n      # } else if (data.media_type == 'person'"
#  b') { #\n        <div class="slim_search_results slim">\n          <div clas'
#  b's="wrapper">\n            <div class="glyphicons_v2 user"></div>\n        '
#  b'    <p>#= data.name # <span>in People</span></p>\n          </div>\n      '
#  b'  </div>\n      # } else { #\n        <div class="slim_search_results slim'
#  b'">\n          <div class="wrapper">\n            <div class="glyphicons_v2'
#  b' search"></div>\n            <p>#= data #</p>\n          </div>\n        </'
#  b'div>\n      # } #\n    </script>\n\n    <script id="delete-confirmation" typ'
#  b'e="text/x-kendo-template">\n      <section class="window_content">\n      '
#  b'  <p class="delete-message">Are you sure?</p>\n\n        <button class="de'
#  b'lete-cancel k-button">No</button>\n        <button class="delete-confirm '
#  b'k-button">Yes</button>\n      </section>\n    </script>\n    <div id="dialo'
#  b'g_window"></div>\n\n    <span id="notification" class="hide"></span>\n    <'
#  b'script id="errorTemplate" type="text/x-kendo-template">\n      <div class'
#  b'="notification error">\n        <span>\n          <h2><span class="glyphic'
#  b'ons_v2 circle-alert invert svg"></span> #= title #</h2>\n          # if ('
#  b'message instanceof Array) { #\n            <ul>\n              # for (var '
#  b'i = 0; i < message.length; i++) { #\n                <li>#= message[i] #<'
#  b'/li>\n              # } #\n            </ul>\n          # } else { #\n      '
#  b'      <p>#= message #</p>\n          # } #\n        </span>\n      </div>\n '
#  b'   </script>\n\n    <script id="successTemplate" type="text/x-kendo-templa'
#  b'te">\n      <div class="notification success">\n        <span>\n          <'
#  b'h2><span class="glyphicons_v2 circle-check invert svg"></span> #= title #</h'
#  b'2>\n          <p>#= message #</p>\n        </span>\n      </div>\n    </scri'
#  b'pt>\n\n    <script id="network_combo_template" type="text/x-kendo-tmpl">\n '
#  b'     <span class="k-state-default image">\n        # if (data.logo_path) '
#  b'{ #\n          <img src="https://media.themoviedb.org/t/p/h15${data.logo_'
#  b'path}" alt="${data.name}" srcset="https://media.themoviedb.org/t/p/h15${data'
#  b'.logo_path} 1x, https://media.themoviedb.org/t/p/h30${data.logo_path} 2x" he'
#  b'ight="15">&nbsp;&nbsp;-&nbsp;\n        # } #\n        ${data.name}# if (da'
#  b'ta.origin_country) { # (${data.origin_country}) # } #\n      </span>\n    '
#  b'</script>\n\n    <script type="application/ld+json">\n      {\n        "@con'
#  b'text": "http://schema.org",\n        "@type": "WebSite",\n        "name": '
#  b'"The Movie Database",\n        "alternateName": "TMDB",\n        "url": "h'
#  b'ttps://www.themoviedb.org"\n      }\n    </script>\n\n    <script type="appl'
#  b'ication/ld+json">\n      {\n         "@context": "http://schema.org",\n    '
#  b'     "@type": "WebSite",\n         "url": "https://www.themoviedb.org/",\n'
#  b'         "potentialAction": {\n           "@type": "SearchAction",\n      '
#  b'     "target": "https://www.themoviedb.org/search?query={search_term_string}'
#  b'",\n           "query-input": "required name=search_term_string"\n        '
#  b' }\n      }\n    </script>\n\n  </body>\n</html>\n')

# %% [markdown]
# ##### 1.d. Infer the type of the variable created in part 1c and display the first 200 characters of the content from the server’s response

# %%
print(f"Type of content variable is [{type(page_content)}]")
print(f"Printing top 200 characters from the content using string slicing")
pprint(page_content[:200])
# Out:
# Type of content variable is [<class 'bytes'>]
# Printing top 200 characters from the content using string slicing
# (b'<!DOCTYPE html>\n<html lang="en" class="no-js">\n  <head>\n    <title>Popul'
#  b'ar Movies &#8212; The Movie Database (TMDB)</title>\n    <meta http-equiv'
#  b'="cleartype" content="on">\n    <meta charset="utf-8">\n  ')

# %% [markdown]
# #### 2. Parse the content of HTML response using the BeautifulSoup library and execute the tasks

# %% [markdown]
# ##### 2.a. From the BeautifulSoup library import the BeautifulSoup class and create an instance of the BeautifulSoup class

# %%
from bs4 import BeautifulSoup

#Create the Soup object using html parse
soup = BeautifulSoup(page_content, 'html.parser')

# %% [markdown]
# ##### 2.b. Extract the title of the parsed web page content

# %%
soup.title.string
# Out:
# 'Popular Movies — The Movie Database (TMDB)'

# %% [markdown]
# ##### 2.c. Write a user defined function to generalize the task presented in Q2a to any URL
#
# <p>
# Write a user defined function to generalize the task presented in Q2a to any URL that
# retrieves the content of the webpage. Your function should take a URL string as an input
# and return a correctly formulated BeautifulSoup instance as the output. In your
# function definition, ensure that appropriate exceptions are raised to the user (through
# status codes) if they pass in malformed/incorrect URLs. Write two test cases for your
# function - one with a working URL and another with an URL that gets a 404 response. (
# 3 marks )
#
# <quote>Note: While pulling the request please specify a user agent string as showed in Q.1.<\quote>
# </p>

# %%
def get_soup_object(url, headers=None):
    """
    This function takes a URL as input and returns the BeautifulSoup object of the webpage.
    It is assumed that the BeautifulSoup and requests libraries are already imported by the caller.
    The function make use of html.parser parser
    
    Args:
    url (string): The url for the web page
    headers (dictionary (String:String)): The headers to be used in the request. Default is None. It is not required to pass 
    any headers. If no values are passed then the default headers of User-Agent and Accept-Language will be used.

    Returns:
    soup (BeautifulSoup object): The BeautifulSoup object of the webpage

    Example:
    >>> get_soup('https://www.test.com')
    """

    # Set the headers conditionally, if no headers are passed
    # These headers are local to the get_soup_object function 
    if headers is None:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36",
            "Accept-Language": "en-US,en;q=0.9"
        }

    try:
        # Send a GET request to the URL with User-Agent and Accept Language Headers
        res = requests.get(url=url, headers=headers)

        if res.status_code != 200:
            raise Exception (
                f"Request failed for [{url}] with StatusCode:[{res.status_code}] and Reason:[{res.reason}]"
            )                   
        return BeautifulSoup(res.content, 'html.parser')    
    except requests.exceptions.RequestException as e:
        raise Exception(f"Request error occoured for [{url}] with error message [{e}]")

# %% [markdown]
# ##### 2.c.i. Test the function get_soup_object(url) with bellow test cases
# * Valid URL
# * Not Existing URL
# * Forbidden URL
# * MalFormed URL

# %%
# Test with a working URL that give 200
try:
    correct_url = 'https://www.examples.com'
    pprint(f"Testing with valid URL: {correct_url}")
    soup = get_soup_object(correct_url)
    pprint(f"Success: Page title = {soup.title.string}")
except Exception as e1:
    pprint(f"Error Occoured: {e1}")

# Test with a non-existing URL that gives 404
try:
    not_existing_url = 'https://www.examples.com/DoNotExists'
    pprint(f"Testing with non-existing URL: {not_existing_url}")
    soup = get_soup_object(not_existing_url)
    pprint(f"Success: Page title = {soup.title.string}")
except Exception as e2:
    pprint(f"Error Occoured: {e2}")

# Test with a forbidden URL that give 403
try:
    forbidden_url = 'https://www.amazon.com'
    pprint(f"Testing with forbidden URL: {forbidden_url}")
    soup = get_soup_object(forbidden_url)
    pprint(f"Success: Page title = {soup.title.string}")
except Exception as e3:
    pprint(f"Error Occoured: {e3}")

# Test with an malformed URL
try:
    malformed_url = 'htt://google.cm'
    pprint(f"Testing with Malformed URL: {malformed_url}")
    soup = get_soup_object(malformed_url)
    pprint(f"Success: Page title = {soup.title.string}")
except Exception as e4:
    pprint(f"Error Occoured: {e4}")
# Out:
# 'Testing with valid URL: https://www.examples.com'
# 'Success: Page title = Examples - Free Interactive Resources'
# 'Testing with non-existing URL: https://www.examples.com/DoNotExists'
# ('Error Occoured: Request failed for [https://www.examples.com/DoNotExists] '
#  'with StatusCode:[404] and Reason:[Not Found]')
# 'Testing with forbidden URL: https://www.amazon.com'
# 'Success: Page title = Amazon.com. Spend less. Smile more.'
# 'Testing with Malformed URL: htt://google.cm'
# ('Error Occoured: Request error occoured for [htt://google.cm] with error '
#  "message [No connection adapters were found for 'htt://google.cm']")

# %% [markdown]
# #### 3. Extract the content of the webpage that hosts a current dated listing of popular movies

# %% [markdown]
# ##### 3.a. Write a function call to the user defined function created in 2c with the url (https://www.themoviedb.org/movie) as an input and store the response in a variable

# %%
try:
    # URL and NEEDED_HEADERS were defined in the start
    soup_tmdb = get_soup_object(url=URL, headers=NEEDED_HEADERS)
    pprint(soup_tmdb.prettify())

    # I'll persist the html to disk in order to inspect the local copy in a browser developer tool
    # and find out specific tags classes to extract in the subsequent sections.
    #with open(file='tmdb_movie_page.html', mode='w', encoding='utf-8') as file:
    #    file.write(soup_tmdb.prettify())
except Exception as e:
    pprint(f"Error Occoured: {e}")
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="no-js" lang="en">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   Popular Movies — The Movie Database (TMDB)\n'
#  '  </title>\n'
#  '  <meta content="on" http-equiv="cleartype"/>\n'
#  '  <meta charset="utf-8"/>\n'
#  '  <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, '
#  'Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" '
#  'name="keywords"/>\n'
#  '  <meta content="yes" name="mobile-web-app-capable"/>\n'
#  '  <meta content="yes" name="apple-mobile-web-app-capable"/>\n'
#  '  <meta content="width=device-width,initial-scale=1" name="viewport"/>\n'
#  '  <meta content="The Movie Database (TMDB) is a popular, user editable '
#  'database for movies and TV shows." name="description"/>\n'
#  '  <meta '
#  'content="/assets/2/v4/icons/mstile-144x144-30e7905a8315a080978ad6aeb71c69222b72c2f75d26dab1224173a96fecc962.png" '
#  'name="msapplication-TileImage"/>\n'
#  '  <meta content="#032541" name="msapplication-TileColor"/>\n'
#  '  <meta content="#032541" name="theme-color"/>\n'
#  '  <link '
#  'href="/assets/2/apple-touch-icon-57ed4b3b0450fd5e9a0c20f34e814b82adaa1085c79bdde2f00ca8787b63d2c4.png" '
#  'rel="apple-touch-icon" sizes="180x180"/>\n'
#  '  <link '
#  'href="/assets/2/favicon-32x32-543a21832c8931d3494a68881f6afcafc58e96c5d324345377f3197a37b367b5.png" '
#  'rel="icon" sizes="32x32" type="image/png"/>\n'
#  '  <link '
#  'href="/assets/2/favicon-16x16-b362d267873ce9c5a39f686a11fe67fec2a72ed25fa8396c11b71aa43c938b11.png" '
#  'rel="icon" sizes="16x16" type="image/png"/>\n'
#  '  <link href="/manifest.json?version=3" rel="manifest"/>\n'
#  '  <link href="https://www.themoviedb.org/movie" rel="canonical"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="TMDB Search" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/Consensus-3cba2c4d050ea63dbf7783173d288faf9ecb2942515a5e7f6e1beecabb2eaf72.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-regular-f38472b9e378b8c936f55a92677f575ab69e414d7cc3706ecfefeacd994b7975.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-italic-48273a74acbc1611b6ef1d0a771bb8ef042b9922b51d5bff560571dddcb5542a.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-300-db9f15a13a9f8b8bc46db7756ab863e8834bd20a7a1124c4c0a5a8f7892f3e99.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-600-6a087a74d78fc7d7b97fa1b0911c4ff3be4ff0bd5144618fd7ddc63ef1777f3a.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link as="font" crossorigin="" '
#  'href="/assets/2/source-sans-pro-v14-vietnamese_latin-ext_latin_greek-ext_greek_cyrillic-ext_cyrillic-700-d67f7dff97d105f4ac5616b00fc7822ce2c33f653ece2f547995e6a71bb7b993.woff2" '
#  'rel="preload" type="font/woff2"/>\n'
#  '  <link '
#  'href="/assets/2/v4/fonts-dcbded27193f5556450c516bf4b553e851bc6d1c8d1c8e6da45a57e3fc278cff.css" '
#  'media="screen" rel="stylesheet"/>\n'
#  '  <link '
#  'href="/assets/2/application-6f8fac3fb42c8f97248a06d21a821ae926df35a7a4319bda760a8fd95e36dd59.css" '
#  'media="screen" rel="stylesheet"/>\n'
#  '  <link '
#  'href="/assets/2/v4/media-d65a112740c7f410033fc1a950402d9cf9753aad44666b98c63db5a6fe7b5416.css" '
#  'media="screen" rel="stylesheet"/>\n'
#  '  <link '
#  'href="/assets/2/v4/discover-b2c3bb76e3d2b2323e842dc4be56a342c51e08c3bb91c6a010e8b401b180f117.css" '
#  'media="screen" rel="stylesheet"/>\n'
#  '  <link '
#  'href="/assets/2/v4/account-cce66521478d16895d1c5e31e821f696433bada2fdee3fc3f9876fac529aa3c7.css" '
#  'media="screen" rel="stylesheet"/>\n'
#  '  <link href="https://www.themoviedb.org/movie" hreflang="x-default" '
#  'rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=af-ZA" '
#  'hreflang="af-ZA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-SA" '
#  'hreflang="ar-SA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=be-BY" '
#  'hreflang="be-BY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=bg-BG" '
#  'hreflang="bg-BG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=bn-BD" '
#  'hreflang="bn-BD" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=br-FR" '
#  'hreflang="br-FR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ca-ES" '
#  'hreflang="ca-ES" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ch-GU" '
#  'hreflang="ch-GU" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=cs-CZ" '
#  'hreflang="cs-CZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=cy-GB" '
#  'hreflang="cy-GB" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=da-DK" '
#  'hreflang="da-DK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=de-DE" '
#  'hreflang="de-DE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=el-GR" '
#  'hreflang="el-GR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-US" '
#  'hreflang="en-US" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=eo-EO" '
#  'hreflang="eo-EO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-ES" '
#  'hreflang="es-ES" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=et-EE" '
#  'hreflang="et-EE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=eu-ES" '
#  'hreflang="eu-ES" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fa-IR" '
#  'hreflang="fa-IR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fi-FI" '
#  'hreflang="fi-FI" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-FR" '
#  'hreflang="fr-FR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ga-IE" '
#  'hreflang="ga-IE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=gd-GB" '
#  'hreflang="gd-GB" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=gl-ES" '
#  'hreflang="gl-ES" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=he-IL" '
#  'hreflang="he-IL" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=hi-IN" '
#  'hreflang="hi-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=hr-HR" '
#  'hreflang="hr-HR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=hu-HU" '
#  'hreflang="hu-HU" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=id-ID" '
#  'hreflang="id-ID" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=it-IT" '
#  'hreflang="it-IT" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ja-JP" '
#  'hreflang="ja-JP" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ka-GE" '
#  'hreflang="ka-GE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=kk-KZ" '
#  'hreflang="kk-KZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=kn-IN" '
#  'hreflang="kn-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ko-KR" '
#  'hreflang="ko-KR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ku-TR" '
#  'hreflang="ku-TR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ky-KG" '
#  'hreflang="ky-KG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=lt-LT" '
#  'hreflang="lt-LT" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=lv-LV" '
#  'hreflang="lv-LV" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ml-IN" '
#  'hreflang="ml-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=mr-IN" '
#  'hreflang="mr-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ms-MY" '
#  'hreflang="ms-MY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=nb-NO" '
#  'hreflang="nb-NO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=nl-NL" '
#  'hreflang="nl-NL" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=no-NO" '
#  'hreflang="no-NO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pa-IN" '
#  'hreflang="pa-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pl-PL" '
#  'hreflang="pl-PL" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pt-PT" '
#  'hreflang="pt-PT" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ro-RO" '
#  'hreflang="ro-RO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ru-RU" '
#  'hreflang="ru-RU" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=si-LK" '
#  'hreflang="si-LK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sk-SK" '
#  'hreflang="sk-SK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sl-SI" '
#  'hreflang="sl-SI" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=so-SO" '
#  'hreflang="so-SO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sq-AL" '
#  'hreflang="sq-AL" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sr-RS" '
#  'hreflang="sr-RS" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sv-SE" '
#  'hreflang="sv-SE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sw-TZ" '
#  'hreflang="sw-TZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ta-IN" '
#  'hreflang="ta-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=te-IN" '
#  'hreflang="te-IN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=tl-PH" '
#  'hreflang="tl-PH" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=th-TH" '
#  'hreflang="th-TH" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=tr-TR" '
#  'hreflang="tr-TR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=uk-UA" '
#  'hreflang="uk-UA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ur-PK" '
#  'hreflang="ur-PK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=uz-UZ" '
#  'hreflang="uz-UZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=vi-VN" '
#  'hreflang="vi-VN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=zh-CN" '
#  'hreflang="zh-CN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=zu-ZA" '
#  'hreflang="zu-ZA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-AE" '
#  'hreflang="ar-AE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-BH" '
#  'hreflang="ar-BH" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-EG" '
#  'hreflang="ar-EG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-IQ" '
#  'hreflang="ar-IQ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-JO" '
#  'hreflang="ar-JO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-LY" '
#  'hreflang="ar-LY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-MA" '
#  'hreflang="ar-MA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-QA" '
#  'hreflang="ar-QA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-YE" '
#  'hreflang="ar-YE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ar-TD" '
#  'hreflang="ar-TD" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ca-AD" '
#  'hreflang="ca-AD" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=de-AT" '
#  'hreflang="de-AT" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=de-CH" '
#  'hreflang="de-CH" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=el-CY" '
#  'hreflang="el-CY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-AG" '
#  'hreflang="en-AG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-AU" '
#  'hreflang="en-AU" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-BB" '
#  'hreflang="en-BB" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-BZ" '
#  'hreflang="en-BZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-CA" '
#  'hreflang="en-CA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-CM" '
#  'hreflang="en-CM" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-GB" '
#  'hreflang="en-GB" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-GG" '
#  'hreflang="en-GG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-GH" '
#  'hreflang="en-GH" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-GI" '
#  'hreflang="en-GI" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-GY" '
#  'hreflang="en-GY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-IE" '
#  'hreflang="en-IE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-JM" '
#  'hreflang="en-JM" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-KE" '
#  'hreflang="en-KE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-LC" '
#  'hreflang="en-LC" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-MW" '
#  'hreflang="en-MW" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-NZ" '
#  'hreflang="en-NZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-PG" '
#  'hreflang="en-PG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-TC" '
#  'hreflang="en-TC" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-ZM" '
#  'hreflang="en-ZM" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=en-ZW" '
#  'hreflang="en-ZW" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-AR" '
#  'hreflang="es-AR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-CL" '
#  'hreflang="es-CL" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-DO" '
#  'hreflang="es-DO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-EC" '
#  'hreflang="es-EC" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-GT" '
#  'hreflang="es-GT" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-GQ" '
#  'hreflang="es-GQ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-HN" '
#  'hreflang="es-HN" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-MX" '
#  'hreflang="es-MX" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-NI" '
#  'hreflang="es-NI" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-PA" '
#  'hreflang="es-PA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-PE" '
#  'hreflang="es-PE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-PY" '
#  'hreflang="es-PY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-SV" '
#  'hreflang="es-SV" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=es-UY" '
#  'hreflang="es-UY" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-BF" '
#  'hreflang="fr-BF" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-CA" '
#  'hreflang="fr-CA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-CD" '
#  'hreflang="fr-CD" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-CI" '
#  'hreflang="fr-CI" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-GF" '
#  'hreflang="fr-GF" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-GP" '
#  'hreflang="fr-GP" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-MC" '
#  'hreflang="fr-MC" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-ML" '
#  'hreflang="fr-ML" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-MU" '
#  'hreflang="fr-MU" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=fr-PF" '
#  'hreflang="fr-PF" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=it-VA" '
#  'hreflang="it-VA" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ms-SG" '
#  'hreflang="ms-SG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=nl-BE" '
#  'hreflang="nl-BE" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pt-AO" '
#  'hreflang="pt-AO" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pt-BR" '
#  'hreflang="pt-BR" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=pt-MZ" '
#  'hreflang="pt-MZ" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=ro-MD" '
#  'hreflang="ro-MD" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sr-ME" '
#  'hreflang="sr-ME" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=sq-XK" '
#  'hreflang="sq-XK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=zh-HK" '
#  'hreflang="zh-HK" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=zh-SG" '
#  'hreflang="zh-SG" rel="alternate"/>\n'
#  '  <link href="https://www.themoviedb.org/movie?language=zh-TW" '
#  'hreflang="zh-TW" rel="alternate"/>\n'
#  '  <script charset="UTF-8" '
#  'data-domain-script="23223fbb-5c84-48df-836d-0a83fb7b2c03" '
#  'src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" '
#  'type="text/javascript">\n'
#  '  </script>\n'
#  '  <script>\n'
#  '   function OptanonWrapper() {}\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/lozad.min-7f803337d01a657607bca6b20e06f371c3895b36a5f2be03a8fa9b5e16c9a83e.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/jquery-3.6.0.min-ff1523fb7389539c84c65aba19260648793bb4f5e29329d2ee8804bc37a3fe6e.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/kendo-93daa31ab3dcca8723478255a3b3c3f0a9e6672dddc612e114391786423c1870.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/kendo-2021.1.204/cultures/kendo.culture.en-US.min-61ce5636474a35333ecff74fe30c528d459bcee29b3b32fc0c58ac77de788b34.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/kendo-2021.1.204/messages/kendo.messages.en-US.min-79da68ae0221b4fd7978805d0c79cc7f682fddace5f2137aa0dae8fe1c5ddacd.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/application-365501d0f2bb3e2b4dceec07a6fd380428faba303d1e80e2a0b837edfd5a2c57.js">\n'
#  '  </script>\n'
#  '  <script '
#  'src="/assets/2/pusher.min-ee61b1e19799dd5aae92a3d91bc970e6147c6fe4395eacf3e499ed1451650f22.js">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="/assets/2/application.desktop-ea69249141a43ef7c6a59a19ee40eface5e171cf03eefffddb488574a66dea02.js">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="/assets/2/kendo-2021.1.204/kendo.calendar.min-ff597f14a778b702ec1cf9967dec754e429caf1558c8b89f0de036e8efe39761.js">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="/assets/2/kendo-2021.1.204/kendo.datepicker.min-9efa21cba900555da428262129f44042706c5abac5644c872d9cac78f010493a.js">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="/assets/2/kendo-2021.1.204/kendo.slider.min-1e770b8fc7facf8ee48d3b0ad7abdfb598ab17cb69add240accc8df5fa2bc919.js">\n'
#  '  </script>\n'
#  '  <script>\n'
#  '   window.mobileDevice = false;\n'
#  '      detected_timezone = Intl.DateTimeFormat().resolvedOptions().timeZone;\n'
#  '        timezone = detected_timezone;\n'
#  '      kendo.culture("en-US");\n'
#  '  </script>\n'
#  '  <script>\n'
#  "   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n"
#  "        new Date().getTime(),event:'gtm.js'});var "
#  'f=d.getElementsByTagName(s)[0],\n'
#  '        '
#  "j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n"
#  '        '
#  "'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n"
#  "        })(window,document,'script','dataLayer','GTM-5QWVXV');\n"
#  '  </script>\n'
#  ' </head>\n'
#  ' <body class="en v4">\n'
#  '  <noscript>\n'
#  '   <iframe height="0" '
#  'src="https://www.googletagmanager.com/ns.html?id=GTM-5QWVXV" '
#  'style="display:none;visibility:hidden" width="0">\n'
#  '   </iframe>\n'
#  '  </noscript>\n'
#  '  <div class="page_wrap movie_wrap">\n'
#  '   <header class="normal smaller no_animation smaller subtle">\n'
#  '    <div class="content">\n'
#  '     <div class="sub_media">\n'
#  '      <div class="nav_wrapper">\n'
#  '       <a aria-label="Home" class="logo" href="/">\n'
#  '        <img alt="The Movie Database (TMDB)" height="20" '
#  'src="/assets/2/v4/logos/v2/blue_short-8e7b30f73a4020692ccca9c88bafe5dcb6f8a62a4c6bc55cd9ba82bb2cd95f6c.svg" '
#  'width="154"/>\n'
#  '       </a>\n'
#  '       <ul class="dropdown_menu navigation primary">\n'
#  '        <li>\n'
#  '         <a aria-label="Movies" class="no_click" href="/movie">\n'
#  '          Movies\n'
#  '         </a>\n'
#  '         <ul>\n'
#  '          <li>\n'
#  '           <a aria-label="Popular" href="/movie">\n'
#  '            Popular\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Now Playing" href="/movie/now-playing">\n'
#  '            Now Playing\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Upcoming" href="/movie/upcoming">\n'
#  '            Upcoming\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Top Rated" href="/movie/top-rated">\n'
#  '            Top Rated\n'
#  '           </a>\n'
#  '          </li>\n'
#  '         </ul>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a aria-label="TV Shows" class="no_click" href="/tv">\n'
#  '          TV Shows\n'
#  '         </a>\n'
#  '         <ul>\n'
#  '          <li>\n'
#  '           <a aria-label="Popular" href="/tv">\n'
#  '            Popular\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Airing Today" href="/tv/airing-today">\n'
#  '            Airing Today\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="On TV" href="/tv/on-the-air">\n'
#  '            On TV\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Top Rated" href="/tv/top-rated">\n'
#  '            Top Rated\n'
#  '           </a>\n'
#  '          </li>\n'
#  '         </ul>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a aria-label="People" class="no_click" href="/person">\n'
#  '          People\n'
#  '         </a>\n'
#  '         <ul>\n'
#  '          <li>\n'
#  '           <a aria-label="Popular People" href="/person">\n'
#  '            Popular People\n'
#  '           </a>\n'
#  '          </li>\n'
#  '         </ul>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a aria-label="More" class="no_click" href="#">\n'
#  '          More\n'
#  '         </a>\n'
#  '         <ul>\n'
#  '          <li>\n'
#  '           <a aria-label="Discussions" href="/discuss">\n'
#  '            Discussions\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Leaderboard" href="/leaderboard">\n'
#  '            Leaderboard\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="Support" href="/talk">\n'
#  '            Support\n'
#  '           </a>\n'
#  '          </li>\n'
#  '          <li>\n'
#  '           <a aria-label="API" href="https://developer.themoviedb.org/docs" '
#  'target="_blank">\n'
#  '            API\n'
#  '           </a>\n'
#  '          </li>\n'
#  '         </ul>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '      <div class="flex">\n'
#  '       <ul class="primary">\n'
#  '        <li class="glyph new_buttons">\n'
#  '         <a aria-label="Create New Movie or TV Show" class="new_icon '
#  'no_click" href="#">\n'
#  '          <span class="glyphicons_v2 plus white">\n'
#  '          </span>\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="translate">\n'
#  '         <div>\n'
#  '          en\n'
#  '         </div>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a aria-label="Login" href="/login">\n'
#  '          Login\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a aria-label="Join TMDB" href="/signup">\n'
#  '          Join TMDB\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="glyph search_buttons">\n'
#  '         <a aria-label="Search" class="search" href="/search">\n'
#  '          <span class="glyphicons_v2 search blue">\n'
#  '          </span>\n'
#  '         </a>\n'
#  '         <a aria-label="Search" class="close hide" href="/search">\n'
#  '          <span class="glyphicons_v2 menu-close invert svg">\n'
#  '          </span>\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <div class="search_bar hide">\n'
#  '     <section class="search show_search_false">\n'
#  '      <div class="sub_media">\n'
#  '       <form accept-charset="utf-8" action="/search" id="search_form" '
#  'method="get">\n'
#  '        <label>\n'
#  '         <input autocomplete="off" autocorrect="off" autofill="off" '
#  'dir="auto" id="search_v4" name="query" placeholder="Search for a movie, tv '
#  'show, person..." spellcheck="false" type="text" value=""/>\n'
#  '        </label>\n'
#  '        <input disabled="" type="submit"/>\n'
#  '       </form>\n'
#  '      </div>\n'
#  '     </section>\n'
#  '    </div>\n'
#  '   </header>\n'
#  '   <main class="smaller subtle show_search_false" id="main">\n'
#  '    <section class="inner_content">\n'
#  '     <div class="media discover" id="media_v4">\n'
#  '      <div class="column_wrapper">\n'
#  '       <div class="content_wrapper">\n'
#  '        <div class="title">\n'
#  '         <h2>\n'
#  '          Popular Movies\n'
#  '         </h2>\n'
#  '        </div>\n'
#  '        <div class="content">\n'
#  '         <div class="">\n'
#  '          <div class="filter_panel card closed">\n'
#  '           <div class="name">\n'
#  '            <h2>\n'
#  '             Sort\n'
#  '            </h2>\n'
#  '            <span class="glyphicons_v2 chevron-right">\n'
#  '            </span>\n'
#  '           </div>\n'
#  '           <div class="filter">\n'
#  '            <h3>\n'
#  '             Sort Results By\n'
#  '            </h3>\n'
#  '            <select class="kendo_dropdown full_width font_size_1" '
#  'id="sort_by" name="sort_by">\n'
#  '             <option selected="" value="popularity.desc">\n'
#  '              Popularity Descending\n'
#  '             </option>\n'
#  '             <option value="popularity.asc">\n'
#  '              Popularity Ascending\n'
#  '             </option>\n'
#  '             <option value="vote_average.desc">\n'
#  '              Rating Descending\n'
#  '             </option>\n'
#  '             <option value="vote_average.asc">\n'
#  '              Rating Ascending\n'
#  '             </option>\n'
#  '             <option value="primary_release_date.desc">\n'
#  '              Release Date Descending\n'
#  '             </option>\n'
#  '             <option value="primary_release_date.asc">\n'
#  '              Release Date Ascending\n'
#  '             </option>\n'
#  '             <option value="title.asc">\n'
#  '              Title (A-Z)\n'
#  '             </option>\n'
#  '             <option value="title.desc">\n'
#  '              Title (Z-A)\n'
#  '             </option>\n'
#  '            </select>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '          <div class="filter_panel card closed">\n'
#  '           <div class="name">\n'
#  '            <h2>\n'
#  '             Where To Watch\n'
#  '             <span>\n'
#  '              33\n'
#  '             </span>\n'
#  '            </h2>\n'
#  '            <span class="glyphicons_v2 chevron-right">\n'
#  '            </span>\n'
#  '           </div>\n'
#  '           <div class="filter">\n'
#  '            <h3>\n'
#  '             My Services\n'
#  '             <span class="tooltip glyphicons_v2 circle-question" '
#  'data-tooltip-id="#ott_tooltip">\n'
#  '             </span>\n'
#  '            </h3>\n'
#  '            <label class="k-form-field">\n'
#  '             <input class="k-checkbox" disabled="" id="my_services" '
#  'name="my_services" type="checkbox" value="true"/>\n'
#  '             <label class="k-checkbox-label" for="my_services">\n'
#  '              Restrict searches to my subscribed services?\n'
#  '             </label>\n'
#  '            </label>\n'
#  '           </div>\n'
#  '           <div class="filter">\n'
#  '            <h3>\n'
#  '             Country\n'
#  '            </h3>\n'
#  '            <div class="font_size_1 kendo_dropdown" id="watch_region" '
#  'style="width: 100%;">\n'
#  '            </div>\n'
#  '            <span id="ott_provider_wrapper">\n'
#  '             <ul class="ott_providers multi_select image" '
#  'id="ott_providers">\n'
#  '              <li class="" data-value="8">\n'
#  '               <a class="no_click" href="#" title="Netflix">\n'
#  '                <img alt="Netflix" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="2">\n'
#  '               <a class="no_click" href="#" title="Apple TV">\n'
#  '                <img alt="Apple TV" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/9ghgSC0MA082EL6HLCW3GalykFD.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="350">\n'
#  '               <a class="no_click" href="#" title="Apple TV Plus">\n'
#  '                <img alt="Apple TV Plus" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="3">\n'
#  '               <a class="no_click" href="#" title="Google Play Movies">\n'
#  '                <img alt="Google Play Movies" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="393">\n'
#  '               <a class="no_click" href="#" title="FlixOlé">\n'
#  '                <img alt="FlixOlé" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="11">\n'
#  '               <a class="no_click" href="#" title="MUBI">\n'
#  '                <img alt="MUBI" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/fj9Y8iIMFUC6952HwxbGixTQPb7.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="232">\n'
#  '               <a class="no_click" href="#" title="Zee5">\n'
#  '                <img alt="Zee5" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/vPIW5b0ebTLj9bFCZypoBbF8wSl.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="511">\n'
#  '               <a class="no_click" href="#" title="iWantTFC">\n'
#  '                <img alt="iWantTFC" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/nHxedyutqerk1yWBsc17mF8gteZ.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="190">\n'
#  '               <a class="no_click" href="#" title="Curiosity Stream">\n'
#  '                <img alt="Curiosity Stream" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="309">\n'
#  '               <a class="no_click" href="#" title="Sun Nxt">\n'
#  '                <img alt="Sun Nxt" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="521">\n'
#  '               <a class="no_click" href="#" title="Spamflix">\n'
#  '                <img alt="Spamflix" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/k2YgZyxij5RcnS1qqUYEUrJB4oQ.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="534">\n'
#  '               <a class="no_click" href="#" title="Argo">\n'
#  '                <img alt="Argo" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/jQMOpRluniNQSEp6V7IvtKxXMW.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="551">\n'
#  '               <a class="no_click" href="#" title="Magellan TV">\n'
#  '                <img alt="Magellan TV" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="554">\n'
#  '               <a class="no_click" href="#" title="BroadwayHD">\n'
#  '                <img alt="BroadwayHD" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="532">\n'
#  '               <a class="no_click" href="#" title="aha">\n'
#  '                <img alt="aha" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/8WerMI8XcZXqPpkHTZNtzMzousF.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="559">\n'
#  '               <a class="no_click" href="#" title="Filmzie">\n'
#  '                <img alt="Filmzie" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/eUBxtrqO26wAJfYOZJOzhQEo3mm.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="567">\n'
#  '               <a class="no_click" href="#" title="True Story">\n'
#  '                <img alt="True Story" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/aRPDQvVcpeY07sjI6lAALMCL0ti.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="569">\n'
#  '               <a class="no_click" href="#" title="DocAlliance Films">\n'
#  '                <img alt="DocAlliance Films" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/vbXJBJVv3u3YWt6ml0l0ldDblXT.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="315">\n'
#  '               <a class="no_click" href="#" title="Hoichoi">\n'
#  '                <img alt="Hoichoi" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="344">\n'
#  '               <a class="no_click" href="#" title="Rakuten Viki">\n'
#  '                <img alt="Rakuten Viki" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/5L2bwr9DhUg28oSMEPRCNwB2y7B.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="445">\n'
#  '               <a class="no_click" href="#" title="Classix">\n'
#  '                <img alt="Classix" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/uFjAjvrKMII0H766QzyHDNkZdKX.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="629">\n'
#  '               <a class="no_click" href="#" title="OSN">\n'
#  '                <img alt="OSN" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/kC6JTo59Gj6I4vJPyBAYGh0sKAE.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="630">\n'
#  '               <a class="no_click" href="#" title="STARZPLAY">\n'
#  '                <img alt="STARZPLAY" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/pDroY6RxYdVw63eAepag4b116Ub.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="581">\n'
#  '               <a class="no_click" href="#" title="iQIYI">\n'
#  '                <img alt="iQIYI" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/c4eVkfMna2VzHzZ8N2vWXUnMrlD.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="119">\n'
#  '               <a class="no_click" href="#" title="Amazon Prime Video">\n'
#  '                <img alt="Amazon Prime Video" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/dQeAar5H991VYporEjUspolDarG.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="677">\n'
#  '               <a class="no_click" href="#" title="Eventive">\n'
#  '                <img alt="Eventive" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/fwx5Ed64TkfWiRH1SOSkc4781Ts.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="692">\n'
#  '               <a class="no_click" href="#" title="Cultpix">\n'
#  '                <img alt="Cultpix" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="701">\n'
#  '               <a class="no_click" href="#" title="FilmBox+">\n'
#  '                <img alt="FilmBox+" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="638">\n'
#  '               <a class="no_click" href="#" title="Public Domain Movies">\n'
#  '                <img alt="Public Domain Movies" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/aN0Y2BNZQBH91JkVOeLTs8IhQrH.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="1715">\n'
#  '               <a class="no_click" href="#" title="Shahid VIP">\n'
#  '                <img alt="Shahid VIP" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="1750">\n'
#  '               <a class="no_click" href="#" title="TOD">\n'
#  '                <img alt="TOD" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/bFxDjHDXP02u1dLPZfTsTC1L6EA.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="1771">\n'
#  '               <a class="no_click" href="#" title="Takflix">\n'
#  '                <img alt="Takflix" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/ed0vz5bryWIhQB5sHiuGvHKnHHn.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '              <li class="" data-value="1958">\n'
#  '               <a class="no_click" href="#" title="AD tv">\n'
#  '                <img alt="AD tv" height="50" '
#  'src="https://media.themoviedb.org/t/p/original/mK8nfCXfwoAa6cAkHUSKCkLEIKK.jpg" '
#  'width="50"/>\n'
#  '                <div>\n'
#  '                 <span class="glyphicons_v2 check white">\n'
#  '                 </span>\n'
#  '                </div>\n'
#  '               </a>\n'
#  '              </li>\n'
#  '             </ul>\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </div>\n'
#  '          <div class="filter_panel card">\n'
#  '           <div class="name" data-callback="filterCallback()">\n'
#  '            <h2>\n'
#  '             Filters\n'
#  '            </h2>\n'
#  '            <span class="glyphicons_v2 chevron-right">\n'
#  '            </span>\n'
#  '           </div>\n'
#  '           <div class="filter">\n'
#  '            <h3>\n'
#  '             Show Me\n'
#  '             <span class="tooltip glyphicons_v2 circle-question" '
#  'data-tooltip-id="#show_me_tooltip">\n'
#  '             </span>\n'
#  '            </h3>\n'
#  '            <label class="k-form-field">\n'
#  '             <input checked="checked" class="k-radio" '
#  'id="show_me_everything" name="show_me" type="radio" value="everything"/>\n'
#  '             <label class="k-radio-label" for="show_me_everything">\n'
#  '              Everything\n'
#  '             </label>\n'
#  '            </label>\n'
#  '            <label class="k-form-field">\n'
#  '             <input class="k-radio" disabled="" id="show_me_not_seen" '
#  'name="show_me" type="radio" value="unwatched"/>\n'
#  '             <label class="k-radio-label" for="show_me_not_seen">\n'
#  "              Movies I Haven't Seen\n"
#  '             </label>\n'
#  '            </label>\n'
#  '            <label class="k-form-field">\n'
#  '             <input class="k-radio" disabled="" id="show_me_seen" '
#  'name="show_me" type="radio" value="watched"/>\n'
#  '             <label class="k-radio-label" for="show_me_seen">\n'
#  '              Movies I Have Seen\n'
#  '             </label>\n'
#  '            </label>\n'
#  '           </div>\n'
#  '           <div class="filter">\n'
#  '            <h3>\n'
#  '             Availabilities\n'
#  '            </h3>\n'
#  '            <label class="k-form-field">\n'
#  '             <input checked="" class="k-checkbox" id="all_availabilities" '
#  'name="all_availabilities" type="checkbox" value="true"/>\n'
#  '             <label class="k-checkbox-label" for="all_availabilities">\n'
#  '              Search all availabilities?\n'
#  '             </label>\n'
#  '            </label>\n'
# ...
#  "        autocompleteInput.on('focus', function (e) {\n"
#  '          var value = autocompleteInput.val();\n'
#  "          if (value == null || value == '') {\n"
#  '            $("#search_v4").data("kendoAutoComplete").search(\'\');\n'
#  '          } else {\n'
#  '            var fieldLength = value.length;\n'
#  '            autocompleteInput[0].setSelectionRange(fieldLength, '
#  'fieldLength);\n'
#  '          }\n'
#  '        });\n'
#  '\n'
#  "        $('li.search_buttons a.search').on('click', function(e) {\n"
#  '          e.preventDefault();\n'
#  '          showSearch(true);\n'
#  '        });\n'
#  '\n'
#  "        $('li.search_buttons a.close').on('click', function(e) {\n"
#  '          e.preventDefault();\n'
#  '          showSearch(false);\n'
#  '        });\n'
#  '\n'
#  "        $('main.show_search_false').on('click', function(e) {\n"
#  '          showSearch(false);\n'
#  '        });\n'
#  '\n'
#  '        $(\'header span.k-i-close[title="clear"]\').on(\'click\', '
#  'function(e) {\n'
#  '          $(\'#search_v4\').data("kendoAutoComplete").focus();\n'
#  '        });\n'
#  '\n'
#  '\n'
#  "        public_media_type_map = { 'movie': 'Movie', 'tv': 'TV Show', "
#  "'person': 'Person' };\n"
#  '\n'
#  '\n'
#  "        $(document).on('keydown', null, 'b', function() {\n"
#  "          if ( $('a.keyboard_s.parent').length ) {\n"
#  "            $('a.keyboard_s.parent')[0].click();\n"
#  '          }\n'
#  '        });\n'
#  '\n'
#  "        $(document).on('keyup', null, 's', function() {\n"
#  "          if ( $('#search_v4').length ) {\n"
#  '            showSearch(true);\n'
#  '          }\n'
#  '        });\n'
#  '\n'
#  "        $(document).on('keyup', null, 'shift+/', function() {\n"
#  '          keyboard_shortcut_popup.open();\n'
#  '        });\n'
#  '\n'
#  "        $(document).on('keydown', null, 'left', function() {\n"
#  "          if ( $('span.previous a.keyboard_s').length ) {\n"
#  "            $('span.previous a.keyboard_s')[0].click();\n"
#  '          }\n'
#  '        });\n'
#  '\n'
#  "        $(document).on('keydown', null, 'right', function() {\n"
#  "          if ( $('span.next a.keyboard_s').length ) {\n"
#  "            $('span.next a.keyboard_s')[0].click();\n"
#  '          }\n'
#  '        });\n'
#  '\n'
#  "        $(document).on('keydown', null, 'm', function() {\n"
#  "          if ( $('#new_shortcut_bar').length ) {\n"
#  '            $("#new_shortcut_bar").focus();\n'
#  '          }\n'
#  '        });\n'
#  '      });\n'
#  '\n'
#  '      var gender_lookup = {\n'
#  "        0: 'two',\n"
#  "        1: 'one',\n"
#  "        2: 'two',\n"
#  "        3: 'two'\n"
#  '      }\n'
#  '  </script>\n'
#  '  <script id="person_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="item profile list_item grid_item">\n'
#  '        <div class="image_content profile">\n'
#  '          <a class="result" href="${data.url}" title="${data.name}" '
#  'alt="${data.name}">\n'
#  '            # if (data.profile_path) { #\n'
#  '              <img class="" '
#  'src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" '
#  'alt="${data.name}" width="45" height="45" '
#  'srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} '
#  '1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} '
#  '2x">\n'
#  '            # } else { #\n'
#  '              <div class="glyphicons_v2 picture profile '
#  '${gender_lookup[data.gender]} grey no_image_holder w45_and_h45"></div>\n'
#  '            # } #\n'
#  '          </a>\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="content">\n'
#  '          <p class="name"><a class="result" href="${data.url}" '
#  'title="${data.name}" alt="${data.name}">${data.name}</a></p>\n'
#  '\n'
#  '          # if (data.known_for) { #\n'
#  '            <p class="sub">${data.known_for}</p>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="person_template_with_known_for" type="text/x-kendo-tmpl">\n'
#  '   <div class="item profile list_item known_for">\n'
#  '        <div class="image_content profile">\n'
#  '          # if (data.profile_path) { #\n'
#  '            <img class="" '
#  'src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" '
#  'alt="${data.name}" width="45" height="45" '
#  'srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} '
#  '1x, https://media.themoviedb.org/t/p/w132_and_h132_face${data.profile_path} '
#  '2x">\n'
#  '          # } else { #\n'
#  '            <div class="glyphicons_v2 picture grey no_image_holder '
#  'w45_and_h45 profile"></div>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="content">\n'
#  '          <p class="name">${data.name}</p>\n'
#  '          # if (data.known_for) { #\n'
#  '            <p class="sub">${data.known_for_department} &bull; '
#  '${data.known_for}</p>\n'
#  '          # } else { #\n'
#  '            <p class="sub">No known credits.</p>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="person_result_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="ac_item profile list_item known_for">\n'
#  '        <div class="image_content profile">\n'
#  '          # if (data.profile_path) { #\n'
#  '            <img class="" '
#  'src="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path}" '
#  'alt="${data.name}" width="45" height="45" '
#  'srcset="https://media.themoviedb.org/t/p/w66_and_h66_face${data.profile_path} '
#  '1x, '
#  'https://media.themoviedb.org/t/p/w132_and_h132_bestv2${data.profile_path} '
#  '2x">\n'
#  '          # } else { #\n'
#  '            <div class="glyphicons_v2 picture grey no_image_holder '
#  'w45_and_h45 profile"></div>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="content">\n'
#  '          <p class="name">${data.name}</p>\n'
#  '          # if (data.known_for) { #\n'
#  '            <p class="sub">\n'
#  '              # if (data.media_type) { #\n'
#  '                <span class="media_type person">#= '
#  'public_media_type_map[data.media_type] # &bull; </span>\n'
#  '              # } #\n'
#  '              # for (var i = 0; i < data.known_for.length; i++) { #\n'
#  '              <span class="comma">#= data.known_for[i].title ? '
#  'data.known_for[i].title : data.known_for[i].name #</span>\n'
#  '              # } #\n'
#  '            </p>\n'
#  '          # } else { #\n'
#  '            <p class="sub">No known credits.</p>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="movie_result_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="ac_results">\n'
#  '        <div class="ac_item poster list_item">\n'
#  '          <div class="image_content poster">\n'
#  '            # if (data.poster_path) { #\n'
#  '              <img class="" '
#  'src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" '
#  'alt="${data.title}" width="45" height="67" '
#  'srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} '
#  '1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} '
#  '2x">\n'
#  '            # } else { #\n'
#  '              <div class="glyphicons_v2 picture grey no_image_holder '
#  'w45_and_h67"></div>\n'
#  '            # } #\n'
#  '          </div>\n'
#  '\n'
#  '          <div class="content">\n'
#  '            <p class="name">${data.title}</p>\n'
#  '            <p class="sub">\n'
#  '              # if (data.media_type) { #\n'
#  '                <span class="media_type movie">#= '
#  'public_media_type_map[data.media_type] # &bull; </span>\n'
#  '              # } #\n'
#  '              # if (data.original_title !== data.title) { #\n'
#  '                <span class="comma"><span class="original_title">#= '
#  'data.original_title #</span></span>\n'
#  '              # } #\n'
#  '              # if (data.release_date) { #\n'
#  '                <span class="comma"><span class="release_date">#= '
#  'data.release_date #</span></span>\n'
#  '              # } #\n'
#  '            </p>\n'
#  '          </div>\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="tv_show_result_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="ac_item poster list_item">\n'
#  '        <div class="image_content poster">\n'
#  '          # if (data.poster_path) { #\n'
#  '            <img class="" '
#  'src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" '
#  'alt="${data.title}" width="45" height="67" '
#  'srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} '
#  '1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} '
#  '2x">\n'
#  '          # } else { #\n'
#  '            <div class="glyphicons_v2 picture grey no_image_holder '
#  'w45_and_h67"></div>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="content">\n'
#  '          <p class="name">${data.name}</p>\n'
#  '          <p class="sub">\n'
#  '            # if (data.media_type) { #\n'
#  '                <span class="media_type tv">#= '
#  'public_media_type_map[data.media_type] # &bull; </span>\n'
#  '              # } #\n'
#  '            # if (data.original_name !== data.name) { #\n'
#  '              <span class="comma"><span class="original_title">#= '
#  'data.original_name #</span></span>\n'
#  '            # } #\n'
#  '            # if (data.first_air_date) { #\n'
#  '              <span class="comma"><span class="release_date">#= '
#  'data.first_air_date #</span></span>\n'
#  '            # } #\n'
#  '          </p>\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="slim_movie_result_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="ac_item poster list_item">\n'
#  '        <div class="image_content poster">\n'
#  '          # if (data.poster_path) { #\n'
#  '            <img class="" '
#  'src="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path}" '
#  'alt="${data.title}" width="45" height="67" '
#  'srcset="https://media.themoviedb.org/t/p/w45_and_h67_bestv2${data.poster_path} '
#  '1x, https://media.themoviedb.org/t/p/w90_and_h134_bestv2${data.poster_path} '
#  '2x">\n'
#  '          # } else { #\n'
#  '            <div class="glyphicons_v2 picture grey no_image_holder '
#  'w45_and_h67"></div>\n'
#  '          # } #\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="content">\n'
#  '          <p class="name">${data.title}</p>\n'
#  '          <p class="sub">\n'
#  '            # if (data.original_title !== data.title) { #\n'
#  '              <span class="comma"><span class="original_title">#= '
#  'data.original_title #</span></span>\n'
#  '            # } #\n'
#  '            # if (data.release_date) { #\n'
#  '              <span class="comma"><span class="release_date">#= '
#  'data.release_date #</span></span>\n'
#  '            # } #\n'
#  '          </p>\n'
#  '        </div>\n'
#  '\n'
#  '        <p><span class="media_type movie">#= '
#  'public_media_type_map[data.media_type] #</span></p>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="multi_search_template" type="text/x-kendo-tmpl">\n'
#  '   <div class="ac_results">\n'
#  "        # if (data.media_type == 'movie') { #\n"
#  '          #= '
#  'kendo.render(kendo.template($("\\\\#movie_result_template").html()), [data]) '
#  '#\n'
#  "        # } else if (data.media_type == 'tv') { #\n"
#  '          #= '
#  'kendo.render(kendo.template($("\\\\#tv_show_result_template").html()), '
#  '[data]) #\n'
#  "        # } else if (data.media_type == 'person') { #\n"
#  '          #= '
#  'kendo.render(kendo.template($("\\\\#person_result_template").html()), '
#  '[data]) #\n'
#  '        # } #\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="search_v4_headerTemplate" type="text/x-kendo-template">\n'
#  '   <div id="trending_search_header_template" '
#  'class="slim_search_results_header">\n'
#  '        <div class="wrapper">\n'
#  '          <h2><span class="glyphicons_v2 trending"></span> Trending</h2>\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="search_no_data_template" type="text/x-kendo-template">\n'
#  '   <div class="slim_search_results_header no_data">\n'
#  '        <div class="wrapper">\n'
#  '          <h2>No Results</h2>\n'
#  '        </div>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="slim_multi_search_template" type="text/x-kendo-tmpl">\n'
#  "   # if (data.media_type == 'movie') { #\n"
#  '        <div class="slim_search_results slim">\n'
#  '          <div class="wrapper">\n'
#  '            <div class="glyphicons_v2 film"></div>\n'
#  '            <p>#= data.name # <span>in Movies</span></p>\n'
#  '          </div>\n'
#  '        </div>\n'
#  "      # } else if (data.media_type == 'tv') { #\n"
#  '        <div class="slim_search_results slim">\n'
#  '          <div class="wrapper">\n'
#  '            <div class="glyphicons_v2 tv"></div>\n'
#  '            <p>#= data.name # <span>in TV Shows</span></p>\n'
#  '          </div>\n'
#  '        </div>\n'
#  "      # } else if (data.media_type == 'person') { #\n"
#  '        <div class="slim_search_results slim">\n'
#  '          <div class="wrapper">\n'
#  '            <div class="glyphicons_v2 user"></div>\n'
#  '            <p>#= data.name # <span>in People</span></p>\n'
#  '          </div>\n'
#  '        </div>\n'
#  '      # } else { #\n'
#  '        <div class="slim_search_results slim">\n'
#  '          <div class="wrapper">\n'
#  '            <div class="glyphicons_v2 search"></div>\n'
#  '            <p>#= data #</p>\n'
#  '          </div>\n'
#  '        </div>\n'
#  '      # } #\n'
#  '  </script>\n'
#  '  <script id="delete-confirmation" type="text/x-kendo-template">\n'
#  '   <section class="window_content">\n'
#  '        <p class="delete-message">Are you sure?</p>\n'
#  '\n'
#  '        <button class="delete-cancel k-button">No</button>\n'
#  '        <button class="delete-confirm k-button">Yes</button>\n'
#  '      </section>\n'
#  '  </script>\n'
#  '  <div id="dialog_window">\n'
#  '  </div>\n'
#  '  <span class="hide" id="notification">\n'
#  '  </span>\n'
#  '  <script id="errorTemplate" type="text/x-kendo-template">\n'
#  '   <div class="notification error">\n'
#  '        <span>\n'
#  '          <h2><span class="glyphicons_v2 circle-alert invert svg"></span> #= '
#  'title #</h2>\n'
#  '          # if (message instanceof Array) { #\n'
#  '            <ul>\n'
#  '              # for (var i = 0; i < message.length; i++) { #\n'
#  '                <li>#= message[i] #</li>\n'
#  '              # } #\n'
#  '            </ul>\n'
#  '          # } else { #\n'
#  '            <p>#= message #</p>\n'
#  '          # } #\n'
#  '        </span>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="successTemplate" type="text/x-kendo-template">\n'
#  '   <div class="notification success">\n'
#  '        <span>\n'
#  '          <h2><span class="glyphicons_v2 circle-check invert svg"></span> #= '
#  'title #</h2>\n'
#  '          <p>#= message #</p>\n'
#  '        </span>\n'
#  '      </div>\n'
#  '  </script>\n'
#  '  <script id="network_combo_template" type="text/x-kendo-tmpl">\n'
#  '   <span class="k-state-default image">\n'
#  '        # if (data.logo_path) { #\n'
#  '          <img src="https://media.themoviedb.org/t/p/h15${data.logo_path}" '
#  'alt="${data.name}" '
#  'srcset="https://media.themoviedb.org/t/p/h15${data.logo_path} 1x, '
#  'https://media.themoviedb.org/t/p/h30${data.logo_path} 2x" '
#  'height="15">&nbsp;&nbsp;-&nbsp;\n'
#  '        # } #\n'
#  '        ${data.name}# if (data.origin_country) { # (${data.origin_country}) '
#  '# } #\n'
#  '      </span>\n'
#  '  </script>\n'
#  '  <script type="application/ld+json">\n'
#  '   {\n'
#  '        "@context": "http://schema.org",\n'
#  '        "@type": "WebSite",\n'
#  '        "name": "The Movie Database",\n'
#  '        "alternateName": "TMDB",\n'
#  '        "url": "https://www.themoviedb.org"\n'
#  '      }\n'
#  '  </script>\n'
#  '  <script type="application/ld+json">\n'
#  '   {\n'
#  '         "@context": "http://schema.org",\n'
#  '         "@type": "WebSite",\n'
#  '         "url": "https://www.themoviedb.org/",\n'
#  '         "potentialAction": {\n'
#  '           "@type": "SearchAction",\n'
#  '           "target": '
#  '"https://www.themoviedb.org/search?query={search_term_string}",\n'
#  '           "query-input": "required name=search_term_string"\n'
#  '         }\n'
#  '      }\n'
#  '  </script>\n'
#  ' </body>\n'
#  '</html>\n')

# %% [markdown]
# ##### 3.b Print the HTML content associated with the first movie displayed on the web page using appropriate HTML tags to access this listing on the object created in part 3a

# %% [markdown]
# By inspecting the HTML we can see all the movies details are enclosed inside a wrapping div with CSS class page_wrapper. Than the movie details are enclosed in an inner DIV tag with CSS class as card and style_1. We will use these 2 classes in find method to get the first occurance of the HTML tags which contains all the HTML for the first listed movie.

# %%
if soup_tmdb:
    first_movie_html = soup_tmdb.find('div', class_='card style_1')
    pprint(first_movie_html.prettify())
else:
    print('HTML source for movie details not found')
# Out:
# ('<div class="card style_1">\n'
#  ' <div class="image">\n'
#  '  <div class="wrapper glyphicons_v2 picture grey no_image_holder">\n'
#  '   <a class="image" href="/movie/533535-deadpool-wolverine" title="Deadpool '
#  '&amp; Wolverine">\n'
#  '    <img alt="Deadpool &amp; Wolverine" class="poster w-full" loading="lazy" '
#  'src="https://media.themoviedb.org/t/p/w220_and_h330_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg" '
#  'srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg '
#  '1x, '
#  'https://media.themoviedb.org/t/p/w440_and_h660_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg '
#  '2x"/>\n'
#  '   </a>\n'
#  '  </div>\n'
#  '  <div class="options" data-id="533535" data-media-type="movie" '
#  'data-object-id="5b3b6b8ec3a3684b8900d8fd">\n'
#  '   <a aria-label="View Item Options" class="no_click" href="#">\n'
#  '    <div class="glyphicons_v2 circle-more white">\n'
#  '    </div>\n'
#  '   </a>\n'
#  '  </div>\n'
#  ' </div>\n'
#  ' <div class="content">\n'
#  '  <div class="consensus tight">\n'
#  '   <div class="outer_ring">\n'
#  '    <div class="user_score_chart 5b3b6b8ec3a3684b8900d8fd" '
#  'data-bar-color="#21d07a" data-percent="78" data-track-color="#204529">\n'
#  '     <div class="percent">\n'
#  '      <span class="icon icon-r78">\n'
#  '      </span>\n'
#  '     </div>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </div>\n'
#  '  <h2>\n'
#  '   <a href="/movie/533535-deadpool-wolverine" title="Deadpool &amp; '
#  'Wolverine">\n'
#  '    Deadpool &amp; Wolverine\n'
#  '   </a>\n'
#  '  </h2>\n'
#  '  <p>\n'
#  '   Jul 24, 2024\n'
#  '  </p>\n'
#  ' </div>\n'
#  ' <div class="hover 533535">\n'
#  ' </div>\n'
#  '</div>\n')

# %% [markdown]
# ##### 3.c. Display the name of the first movie using appropriate HTML tags to access this listing on the object created in part 3a
#
# <small> Note: Since it's mentioned in the task that the object to used is the one that was created in 3a, hence we are directly using soup_tmdb oject. Otherwise the first_movie_html object parsed in 3b can also be utilised.
# </small>

# %%
if soup_tmdb:
    first_movie = soup_tmdb.find('div', class_='card style_1')
    if first_movie:
        title = first_movie.find('h2').get_text(strip=True)
        print('Movie Title =', title)
else:
    print('Movie title not found')
# Out:
# Movie Title = Deadpool & Wolverine

# %% [markdown]
# ##### 3.d. Display the user rating of the first movie by using appropriate HTML tags to access this listing on the object created in part 3a

# %% [markdown]
# <p>
# Instead of a user rating the latest imdb page have user score chart as a percentage. We will extract this info and display it.</p>
#
# <small> Note: Since it's mentioned in the task that the object to used is the one that was created in 3a, hence we are directly using soup_tmdb oject. Otherwise the first_movie_html object parsed in 3b can also be utilised.
# </small>

# %%
if soup_tmdb:
    first_movie = soup_tmdb.find('div', class_=['card style_1'])
    if first_movie:
        score_chart = first_movie.find('div', class_='user_score_chart')
        if score_chart:
            score = score_chart.get('data-percent', 'not rated')
            print('User Score Percentage =', f"{score}%")
        else:
            print('not rated')
# Out:
# User Score Percentage = 78%

# %% [markdown]
# ##### 3.e. For the first movie, extract the part of the url following the string (https://www.themoviedb.org/) using the appropriate HTML tags to extract this portion on the object created in part 3a (do not use built-in string methods).
#
# <p>For example, if the first movie on the web page had the URL (https://www.themoviedb.org/movie/779782) your output should be movie/779782</p>
#
# <small> Note: Since it's mentioned in the task that the object to used is the one that was created in 3a, hence we are directly using soup_tmdb oject. Otherwise the first_movie_html object parsed in 3b can also be utilised.
# </small>

# %% [markdown]
# The url tag for the movie is already in the relative URL format, hence we don't have to extract it. We will use the slicing technique of string to remove the first / from the relative url
#
# ```
# <a class="image" href="/movie/533535-deadpool-wolverine" title="Deadpool &amp; Wolverine" />
# ```

# %%
if soup_tmdb:
    first_movie = soup_tmdb.find('div', class_=['card style_1'])
    if first_movie:
        relative_url = first_movie.find('a', class_='image')['href'][1:]
        print(relative_url)
    else:
        print('Relative URL for movie not found')
# Out:
# movie/533535-deadpool-wolverine

# %% [markdown]
# #### 4. Write user defined functions for each subsection below (i.e., Q4 a, Q4b, Q4c, Q4d, and Q4e) to return

# %% [markdown]
# ##### 4.a. Titles of all the movies on the page as a Python list
#
# <small>Note For Q4a, Q4b, Q4c: the response object created in Q3a</small>

# %%
def get_movie_titles(obj_soup):
    """
    Extracts movie titles from a TMDB BeautifulSoup object.
    :param obj_soup: A BeautifulSoup object of the page
    :return: A list of movie titles
    """
    titles = []
    #get all movie cards
    movies = obj_soup.find_all('div', class_=['card style_1'])

    titles = [movie.find('h2').get_text(strip=True) for movie in movies]
    return titles

# %% [markdown]
# ##### We have our soup object in soup_tmdb variable which we will use here

# %%
titles = get_movie_titles(soup_tmdb)
pprint(titles)
# Out:
# ['Deadpool & Wolverine',
#  'Twisters',
#  'Despicable Me 4',
#  'Inside Out 2',
#  'Bad Boys: Ride or Die',
#  'Kill',
#  'A Quiet Place: Day One',
#  'Mayhem!',
#  'Alien: Romulus',
#  'It Ends with Us',
#  'Prey',
#  'Dragonkeeper',
#  'Saving Bikini Bottom: The Sandy Cheeks Movie',
#  'The Instigators',
#  'One Fast Move',
#  'The Garfield Movie',
#  'Furiosa: A Mad Max Saga',
#  'Kingdom of the Planet of the Apes',
#  'The Convert',
#  'Breaking and Re-entering']

# %% [markdown]
# ##### 4.b. User ratings of all the movies on the page as a Python list
#
# <small>Note For Q4a, Q4b, Q4c: the response object created in Q3a</small>

# %%
def get_user_ratings(obj_soup):
    """
    Extracts user ratings from a given soup object of TMDB movies cards.
    :param obj_soup: The soup object of TMBD movies page
    :return: A list of user ratings
    """
    ratings = []
    #get all movie cards
    movies = obj_soup.find_all('div', class_=['card style_1'])

    for movie in movies:
        score_chart = movie.find('div', class_='user_score_chart')
        if score_chart:
            score = score_chart.get('data-percent', 'not rated')
        else:
            score = 'not rated'
        ratings.append(score)
    return ratings

# %%
user_ratings = get_user_ratings(soup_tmdb)
pprint(user_ratings)
# Out:
# ['78',
#  '71',
#  '73',
#  '76',
#  '76',
#  '70',
#  '69',
#  '67',
#  '74',
#  '70',
#  '65',
#  '69',
#  '65',
#  '65',
#  '67',
#  '72',
#  '76',
#  '72',
#  '63',
#  '64']

# %% [markdown]
# ##### 4.c. HTML content of all the individual pages of movies collected into a Python list.
#
# <small>Note For Q4a, Q4b, Q4c: the response object created in Q3a</small>

# %% [markdown]
# It is mentioned to collect all the html in a python list, while in FAQ it was clarified that the relative URL needs to be collected. I'll collect both as it's not clear what exactly is needed.

# %%
def get_movies_html(obj_soup):
    """
    Extracts movie information from a BeautifulSoup object of TMBD movies page.
    :param obj_soup: The soup object representation of TMDB movies page
    :return: A list of dictionaries containing movie information
    """
    movies_html = []
    #get all movie cards
    movies = obj_soup.find_all('div', class_=['card style_1'])        
    movies_html = [movie for movie in movies]
    return movies_html

def get_movies_details_url(obj_soup):
    """
    Extracts the URL of the movie details page from a BeautifulSoup object of TMBD movies page
    :param obj_soup: The soup object representation of TMDB movies page
    :return: A list of URLs of the movie details page
    """
    movies_details_url = []
    #get all movie cards
    movies = obj_soup.find_all('div', class_=['card style_1'])
    movies_details_url = [movie.find('a', class_='image')['href'][1:] for movie in movies]
    return movies_details_url

# %%
movies_html = get_movies_html(soup_tmdb)
pprint(movies_html)
# Out:
# [<div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/533535-deadpool-wolverine" title="Deadpool &amp; Wolverine">
# <img alt="Deadpool &amp; Wolverine" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="533535" data-media-type="movie" data-object-id="5b3b6b8ec3a3684b8900d8fd">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5b3b6b8ec3a3684b8900d8fd" data-bar-color="#21d07a" data-percent="78" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r78"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/533535-deadpool-wolverine" title="Deadpool &amp; Wolverine">Deadpool &amp; Wolverine</a></h2>
# <p>Jul 24, 2024</p>
# </div>
# <div class="hover 533535"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/718821-twisters" title="Twisters">
# <img alt="Twisters" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/pjnD08FlMAIXsfOLKQbvmO0f0MD.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/pjnD08FlMAIXsfOLKQbvmO0f0MD.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/pjnD08FlMAIXsfOLKQbvmO0f0MD.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="718821" data-media-type="movie" data-object-id="5ef451d4bccf1e0038383e47">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5ef451d4bccf1e0038383e47" data-bar-color="#21d07a" data-percent="71" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r71"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/718821-twisters" title="Twisters">Twisters</a></h2>
# <p>Jul 10, 2024</p>
# </div>
# <div class="hover 718821"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/519182-despicable-me-4" title="Despicable Me 4">
# <img alt="Despicable Me 4" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/wWba3TaojhK7NdycRhoQpsG0FaH.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/wWba3TaojhK7NdycRhoQpsG0FaH.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/wWba3TaojhK7NdycRhoQpsG0FaH.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="519182" data-media-type="movie" data-object-id="5ad86d1ec3a368718f0112dc">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5ad86d1ec3a368718f0112dc" data-bar-color="#21d07a" data-percent="73" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r73"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/519182-despicable-me-4" title="Despicable Me 4">Despicable Me 4</a></h2>
# <p>Jun 20, 2024</p>
# </div>
# <div class="hover 519182"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1022789-inside-out-2" title="Inside Out 2">
# <img alt="Inside Out 2" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1022789" data-media-type="movie" data-object-id="631bd66867dcc90082814ca2">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 631bd66867dcc90082814ca2" data-bar-color="#21d07a" data-percent="76" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r76"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1022789-inside-out-2" title="Inside Out 2">Inside Out 2</a></h2>
# <p>Jun 13, 2024</p>
# </div>
# <div class="hover 1022789"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/573435-bad-boys-ride-or-die" title="Bad Boys: Ride or Die">
# <img alt="Bad Boys: Ride or Die" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/oGythE98MYleE6mZlGs5oBGkux1.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/oGythE98MYleE6mZlGs5oBGkux1.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/oGythE98MYleE6mZlGs5oBGkux1.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="573435" data-media-type="movie" data-object-id="5c3336ec0e0a2666043d9705">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5c3336ec0e0a2666043d9705" data-bar-color="#21d07a" data-percent="76" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r76"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/573435-bad-boys-ride-or-die" title="Bad Boys: Ride or Die">Bad Boys: Ride or Die</a></h2>
# <p>Jun 05, 2024</p>
# </div>
# <div class="hover 573435"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1160018-kill" title="Kill">
# <img alt="Kill" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/m2zXTuNPkywdYLyWlVyJZW2QOJH.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/m2zXTuNPkywdYLyWlVyJZW2QOJH.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/m2zXTuNPkywdYLyWlVyJZW2QOJH.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1160018" data-media-type="movie" data-object-id="64cbcb7e4fd14100ca85da4d">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 64cbcb7e4fd14100ca85da4d" data-bar-color="#21d07a" data-percent="70" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r70"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1160018-kill" title="Kill">Kill</a></h2>
# <p>Jul 03, 2024</p>
# </div>
# <div class="hover 1160018"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/762441-a-quiet-place-day-one" title="A Quiet Place: Day One">
# <img alt="A Quiet Place: Day One" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/hU42CRk14JuPEdqZG3AWmagiPAP.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/hU42CRk14JuPEdqZG3AWmagiPAP.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/hU42CRk14JuPEdqZG3AWmagiPAP.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="762441" data-media-type="movie" data-object-id="5fa997eb34e152003f7c67d1">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5fa997eb34e152003f7c67d1" data-bar-color="#d2d531" data-percent="69" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r69"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/762441-a-quiet-place-day-one" title="A Quiet Place: Day One">A Quiet Place: Day One</a></h2>
# <p>Jun 26, 2024</p>
# </div>
# <div class="hover 762441"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/959092-farang" title="Mayhem!">
# <img alt="Mayhem!" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/u9035lysUz3ccloQt0SeIp1Mu8a.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/u9035lysUz3ccloQt0SeIp1Mu8a.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/u9035lysUz3ccloQt0SeIp1Mu8a.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="959092" data-media-type="movie" data-object-id="624c98911d1bf400670091c8">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 624c98911d1bf400670091c8" data-bar-color="#d2d531" data-percent="67" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r67"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/959092-farang" title="Mayhem!">Mayhem!</a></h2>
# <p>Jun 28, 2023</p>
# </div>
# <div class="hover 959092"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/945961-alien-romulus" title="Alien: Romulus">
# <img alt="Alien: Romulus" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/b33nnKl1GSFbao4l3fZDDqsMx0F.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/b33nnKl1GSFbao4l3fZDDqsMx0F.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/b33nnKl1GSFbao4l3fZDDqsMx0F.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="945961" data-media-type="movie" data-object-id="6222913cc2823a00421925c8">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 6222913cc2823a00421925c8" data-bar-color="#21d07a" data-percent="74" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r74"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/945961-alien-romulus" title="Alien: Romulus">Alien: Romulus</a></h2>
# <p>Aug 13, 2024</p>
# </div>
# <div class="hover 945961"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1079091-it-ends-with-us" title="It Ends with Us">
# <img alt="It Ends with Us" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1079091" data-media-type="movie" data-object-id="63d314665a07f500dc9ea38a">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 63d314665a07f500dc9ea38a" data-bar-color="#21d07a" data-percent="70" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r70"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1079091-it-ends-with-us" title="It Ends with Us">It Ends with Us</a></h2>
# <p>Aug 07, 2024</p>
# </div>
# <div class="hover 1079091"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1129598-prey" title="Prey">
# <img alt="Prey" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/5wAlO5zZ3IyzLBAf7cp5WejalmG.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/5wAlO5zZ3IyzLBAf7cp5WejalmG.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/5wAlO5zZ3IyzLBAf7cp5WejalmG.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1129598" data-media-type="movie" data-object-id="6469f2a62bcf67011bf3a896">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 6469f2a62bcf67011bf3a896" data-bar-color="#d2d531" data-percent="65" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r65"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1129598-prey" title="Prey">Prey</a></h2>
# <p>Mar 15, 2024</p>
# </div>
# <div class="hover 1129598"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/588648-dragonkeeper" title="Dragonkeeper">
# <img alt="Dragonkeeper" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="588648" data-media-type="movie" data-object-id="5c8d94e40e0a2612f1547936">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5c8d94e40e0a2612f1547936" data-bar-color="#d2d531" data-percent="69" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r69"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/588648-dragonkeeper" title="Dragonkeeper">Dragonkeeper</a></h2>
# <p>Apr 11, 2024</p>
# </div>
# <div class="hover 588648"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/831815-saving-bikini-bottom-the-sandy-cheeks-movie" title="Saving Bikini Bottom: The Sandy Cheeks Movie">
# <img alt="Saving Bikini Bottom: The Sandy Cheeks Movie" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="831815" data-media-type="movie" data-object-id="60a6ccb91689350029c3d27e">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 60a6ccb91689350029c3d27e" data-bar-color="#d2d531" data-percent="65" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r65"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/831815-saving-bikini-bottom-the-sandy-cheeks-movie" title="Saving Bikini Bottom: The Sandy Cheeks Movie">Saving Bikini Bottom: The Sandy Cheeks Movie</a></h2>
# <p>Aug 02, 2024</p>
# </div>
# <div class="hover 831815"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1059064-the-instigators" title="The Instigators">
# <img alt="The Instigators" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/thI9pM7Qu43f42sOOl5wy75UAo.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/thI9pM7Qu43f42sOOl5wy75UAo.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/thI9pM7Qu43f42sOOl5wy75UAo.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1059064" data-media-type="movie" data-object-id="63924341cee2f6007afcffc6">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 63924341cee2f6007afcffc6" data-bar-color="#d2d531" data-percent="65" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r65"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1059064-the-instigators" title="The Instigators">The Instigators</a></h2>
# <p>Aug 09, 2024</p>
# </div>
# <div class="hover 1059064"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1281826-one-fast-move" title="One Fast Move">
# <img alt="One Fast Move" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/hdBUjfbdr1ymS0kycAT7qguOmWA.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/hdBUjfbdr1ymS0kycAT7qguOmWA.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/hdBUjfbdr1ymS0kycAT7qguOmWA.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1281826" data-media-type="movie" data-object-id="662f0d93072166012469f89f">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 662f0d93072166012469f89f" data-bar-color="#d2d531" data-percent="67" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r67"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1281826-one-fast-move" title="One Fast Move">One Fast Move</a></h2>
# <p>Aug 07, 2024</p>
# </div>
# <div class="hover 1281826"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/748783-the-garfield-movie" title="The Garfield Movie">
# <img alt="The Garfield Movie" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/xYduFGuch9OwbCOEUiamml18ZoB.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/xYduFGuch9OwbCOEUiamml18ZoB.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/xYduFGuch9OwbCOEUiamml18ZoB.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="748783" data-media-type="movie" data-object-id="5f75bdf158efd30037b04d9b">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5f75bdf158efd30037b04d9b" data-bar-color="#21d07a" data-percent="72" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r72"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/748783-the-garfield-movie" title="The Garfield Movie">The Garfield Movie</a></h2>
# <p>Apr 30, 2024</p>
# </div>
# <div class="hover 748783"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/786892-furiosa-a-mad-max-saga" title="Furiosa: A Mad Max Saga">
# <img alt="Furiosa: A Mad Max Saga" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/iADOJ8Zymht2JPMoy3R7xceZprc.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/iADOJ8Zymht2JPMoy3R7xceZprc.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/iADOJ8Zymht2JPMoy3R7xceZprc.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="786892" data-media-type="movie" data-object-id="6003f7d4cb3084003edde0ec">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 6003f7d4cb3084003edde0ec" data-bar-color="#21d07a" data-percent="76" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r76"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/786892-furiosa-a-mad-max-saga" title="Furiosa: A Mad Max Saga">Furiosa: A Mad Max Saga</a></h2>
# <p>May 22, 2024</p>
# </div>
# <div class="hover 786892"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/653346-kingdom-of-the-planet-of-the-apes" title="Kingdom of the Planet of the Apes">
# <img alt="Kingdom of the Planet of the Apes" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/gKkl37BQuKTanygYQG1pyYgLVgf.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/gKkl37BQuKTanygYQG1pyYgLVgf.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/gKkl37BQuKTanygYQG1pyYgLVgf.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="653346" data-media-type="movie" data-object-id="5de6f6133faba00015133c4d">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 5de6f6133faba00015133c4d" data-bar-color="#21d07a" data-percent="72" data-track-color="#204529">
# <div class="percent">
# <span class="icon icon-r72"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/653346-kingdom-of-the-planet-of-the-apes" title="Kingdom of the Planet of the Apes">Kingdom of the Planet of the Apes</a></h2>
# <p>May 09, 2024</p>
# </div>
# <div class="hover 653346"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1066262-the-convert" title="The Convert">
# <img alt="The Convert" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/e5ZqqPlhKstzB4geibpZh38w7Pq.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/e5ZqqPlhKstzB4geibpZh38w7Pq.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/e5ZqqPlhKstzB4geibpZh38w7Pq.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1066262" data-media-type="movie" data-object-id="63aa3959e4b5760085bf713f">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 63aa3959e4b5760085bf713f" data-bar-color="#d2d531" data-percent="63" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r63"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1066262-the-convert" title="The Convert">The Convert</a></h2>
# <p>Mar 14, 2024</p>
# </div>
# <div class="hover 1066262"></div>
# </div>,
#  <div class="card style_1">
# <div class="image">
# <div class="wrapper glyphicons_v2 picture grey no_image_holder">
# <a class="image" href="/movie/1166073" title="Breaking and Re-entering">
# <img alt="Breaking and Re-entering" class="poster w-full" loading="lazy" src="https://media.themoviedb.org/t/p/w220_and_h330_face/qYdS4KIdCmJr3WB4CJYnoGaTVbv.jpg" srcset="https://media.themoviedb.org/t/p/w220_and_h330_face/qYdS4KIdCmJr3WB4CJYnoGaTVbv.jpg 1x, https://media.themoviedb.org/t/p/w440_and_h660_face/qYdS4KIdCmJr3WB4CJYnoGaTVbv.jpg 2x"/>
# </a>
# </div>
# <div class="options" data-id="1166073" data-media-type="movie" data-object-id="64dd98c8a3b5e600ff4d2a64">
# <a aria-label="View Item Options" class="no_click" href="#"><div class="glyphicons_v2 circle-more white"></div></a>
# </div>
# </div>
# <div class="content">
# <div class="consensus tight">
# <div class="outer_ring">
# <div class="user_score_chart 64dd98c8a3b5e600ff4d2a64" data-bar-color="#d2d531" data-percent="64" data-track-color="#423d0f">
# <div class="percent">
# <span class="icon icon-r64"></span>
# </div>
# </div>
# </div>
# </div>
# <h2><a href="/movie/1166073" title="Breaking and Re-entering">Breaking and Re-entering</a></h2>
# <p>Feb 08, 2024</p>
# </div>
# <div class="hover 1166073"></div>
# </div>]

# %%
movies_url_list = get_movies_details_url(soup_tmdb)
pprint(movies_url_list)
# Out:
# ['movie/533535-deadpool-wolverine',
#  'movie/718821-twisters',
#  'movie/519182-despicable-me-4',
#  'movie/1022789-inside-out-2',
#  'movie/573435-bad-boys-ride-or-die',
#  'movie/1160018-kill',
#  'movie/762441-a-quiet-place-day-one',
#  'movie/959092-farang',
#  'movie/945961-alien-romulus',
#  'movie/1079091-it-ends-with-us',
#  'movie/1129598-prey',
#  'movie/588648-dragonkeeper',
#  'movie/831815-saving-bikini-bottom-the-sandy-cheeks-movie',
#  'movie/1059064-the-instigators',
#  'movie/1281826-one-fast-move',
#  'movie/748783-the-garfield-movie',
#  'movie/786892-furiosa-a-mad-max-saga',
#  'movie/653346-kingdom-of-the-planet-of-the-apes',
#  'movie/1066262-the-convert',
#  'movie/1166073']

# %% [markdown]
# #### 4.d. Genres of all the movies on the page as a Python list
#
# <small>For Q4d, Q4e: the list output from Q4c</small>

# %% [markdown]
# <p>
#     Genere is itself a list, hence, we will pass the list of relative URLs for the movies to the function and the function will return a list of list containing all genere for each movie represented by the each URL in the list.
#
#     Input: List of relative URLs for movies details page
#     Output: List of Genere for each movie in the input list
# <p>

# %%
def get_movies_genere(movie_details_url, debug=True):
    """
    This function takes a movie details URL and returns a list of genres of the movie.
    Args:
    movie_details_url (str): The URLs of the all the movie details pages.
    debug (bool): If True, it will print the genres of the movie. Default is True
    Returns: List of movies generes for each URL's in the input list
    """
    movie_genere = []
    for rel_url in movie_details_url:
        # Construct the detailed movie URL
        details_url = format(f"https://www.themoviedb.org/{rel_url}")
        if debug: print(f"Fetching generes for [{details_url}]")
        # Get the soup object for the detailed page
        soup = get_soup_object(details_url)        
        if soup:
            generes = soup.find('span', class_='genres')
            if generes:
                g = [a.get_text(strip=True) for a in generes.find_all('a')]
            else:
                g = []
        movie_genere.append(g)
    return movie_genere

# %%
movie_genere = get_movies_genere(get_movies_details_url(soup_tmdb))
pprint(movie_genere)
# Out:
# Fetching generes for [https://www.themoviedb.org/movie/533535-deadpool-wolverine]
# Fetching generes for [https://www.themoviedb.org/movie/718821-twisters]
# Fetching generes for [https://www.themoviedb.org/movie/519182-despicable-me-4]
# Fetching generes for [https://www.themoviedb.org/movie/1022789-inside-out-2]
# Fetching generes for [https://www.themoviedb.org/movie/573435-bad-boys-ride-or-die]
# Fetching generes for [https://www.themoviedb.org/movie/1160018-kill]
# Fetching generes for [https://www.themoviedb.org/movie/762441-a-quiet-place-day-one]
# Fetching generes for [https://www.themoviedb.org/movie/959092-farang]
# Fetching generes for [https://www.themoviedb.org/movie/945961-alien-romulus]
# Fetching generes for [https://www.themoviedb.org/movie/1079091-it-ends-with-us]
# Fetching generes for [https://www.themoviedb.org/movie/1129598-prey]
# Fetching generes for [https://www.themoviedb.org/movie/588648-dragonkeeper]
# Fetching generes for [https://www.themoviedb.org/movie/831815-saving-bikini-bottom-the-sandy-cheeks-movie]
# Fetching generes for [https://www.themoviedb.org/movie/1059064-the-instigators]
# Fetching generes for [https://www.themoviedb.org/movie/1281826-one-fast-move]
# Fetching generes for [https://www.themoviedb.org/movie/748783-the-garfield-movie]
# Fetching generes for [https://www.themoviedb.org/movie/786892-furiosa-a-mad-max-saga]
# Fetching generes for [https://www.themoviedb.org/movie/653346-kingdom-of-the-planet-of-the-apes]
# Fetching generes for [https://www.themoviedb.org/movie/1066262-the-convert]
# Fetching generes for [https://www.themoviedb.org/movie/1166073]
# [['Action', 'Comedy', 'Science Fiction'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Animation', 'Family', 'Comedy', 'Action'],
#  ['Animation', 'Family', 'Adventure', 'Comedy'],
#  ['Action', 'Crime', 'Thriller', 'Comedy'],
#  ['Action', 'Crime'],
#  ['Horror', 'Science Fiction', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Horror', 'Science Fiction'],
#  ['Drama', 'Romance'],
#  ['Action', 'Thriller'],
#  ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy'],
#  ['Animation', 'Comedy', 'Adventure', 'Family'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Drama', 'Romance'],
#  ['Animation', 'Comedy', 'Family', 'Adventure'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Science Fiction', 'Adventure', 'Action'],
#  ['Action', 'Drama'],
#  ['Action', 'Comedy']]

# %% [markdown]
# #### 4.e. Cast of all the movies on the page as a Python list
#
# <small>For Q4d, Q4e: the list output from Q4c</small>

# %% [markdown]
# <p>
#     The cast for each movie have 2 details, Actor and Character. Hence, we will pass a list of movies relative URL and the function will return a list of Dictionary objects containing each cast member for each movie in the format of Actor: Name, Character: Name
#
#     Input: List of relative URLs for movies details page
#     Output: List of Dictionary objects containing each cast member for each movie in the list
# </p>

# %%
def get_movies_cast(movie_details_url, debug=True):
    """
    Get the cast of all the movies from the movie details URL list.
    Args:
    movie_details_url (list): List of URLs of movie details pages.
    debug (bool): If True, print debug messages. Default is True.
    Returns: List of actors in the movie in Actor as Character format
    """
    movies_actor_list = []
    for rel_url in movie_details_url:
        # Construct the detailed movie URL
        details_url = format(f"https://www.themoviedb.org/{rel_url}")
        if debug: print(f"Fetching cast for [{details_url}]")
        # Get the soup object for the detailed page
        soup = get_soup_object(details_url)        
        if soup:            
            casts = soup.find_all('li', class_='card')
            actor_list = []
            if casts:                
                for cst in casts:
                    actor = cst.find('p').find('a').get_text(strip=True)
                    character = cst.find('p', class_=['character']).get_text(strip=True)
                    actor_list.append(f"{actor}, as {character}" if character else f"{actor},")
            movies_actor_list.append(actor_list)
    return movies_actor_list

# %%
movie_actor_list = get_movies_cast(get_movies_details_url(soup_tmdb)) 
pprint(movie_actor_list)
# Out:
# Fetching cast for [https://www.themoviedb.org/movie/533535-deadpool-wolverine]
# Fetching cast for [https://www.themoviedb.org/movie/718821-twisters]
# Fetching cast for [https://www.themoviedb.org/movie/519182-despicable-me-4]
# Fetching cast for [https://www.themoviedb.org/movie/1022789-inside-out-2]
# Fetching cast for [https://www.themoviedb.org/movie/573435-bad-boys-ride-or-die]
# Fetching cast for [https://www.themoviedb.org/movie/1160018-kill]
# Fetching cast for [https://www.themoviedb.org/movie/762441-a-quiet-place-day-one]
# Fetching cast for [https://www.themoviedb.org/movie/959092-farang]
# Fetching cast for [https://www.themoviedb.org/movie/945961-alien-romulus]
# Fetching cast for [https://www.themoviedb.org/movie/1079091-it-ends-with-us]
# Fetching cast for [https://www.themoviedb.org/movie/1129598-prey]
# Fetching cast for [https://www.themoviedb.org/movie/588648-dragonkeeper]
# Fetching cast for [https://www.themoviedb.org/movie/831815-saving-bikini-bottom-the-sandy-cheeks-movie]
# Fetching cast for [https://www.themoviedb.org/movie/1059064-the-instigators]
# Fetching cast for [https://www.themoviedb.org/movie/1281826-one-fast-move]
# Fetching cast for [https://www.themoviedb.org/movie/748783-the-garfield-movie]
# Fetching cast for [https://www.themoviedb.org/movie/786892-furiosa-a-mad-max-saga]
# Fetching cast for [https://www.themoviedb.org/movie/653346-kingdom-of-the-planet-of-the-apes]
# Fetching cast for [https://www.themoviedb.org/movie/1066262-the-convert]
# Fetching cast for [https://www.themoviedb.org/movie/1166073]
# [['Ryan Reynolds, as Wade Wilson / Deadpool / Nicepool',
#   'Hugh Jackman, as Logan / Wolverine',
#   'Emma Corrin, as Cassandra Nova',
#   'Matthew Macfadyen, as Mr. Paradox',
#   'Dafne Keen, as Laura / X-23',
#   'Jon Favreau, as Happy Hogan',
#   'Morena Baccarin, as Vanessa',
#   'Rob Delaney, as Peter',
#   'Leslie Uggams, as Blind Al'],
#  ['Daisy Edgar-Jones, as Kate',
#   'Glen Powell, as Tyler',
#   'Anthony Ramos, as Javi',
#   'Brandon Perea, as Boone',
#   'Maura Tierney, as Cathy',
#   'Harry Hadden-Paton, as Ben',
#   'Sasha Lane, as Lily',
#   'Daryl McCormack, as Jeb',
#   'Kiernan Shipka, as Addy'],
#  ['Steve Carell, as Gru (voice)',
#   'Kristen Wiig, as Lucy (voice)',
#   'Will Ferrell, as Maxime (voice)',
#   'Sofía Vergara, as Valentina (voice)',
#   'Miranda Cosgrove, as Margo (voice)',
#   'Dana Gaier, as Edith (voice)',
#   'Madison Polan, as Agnes (voice)',
#   'Pierre Coffin, as Minions (voice)',
#   'Chris Renaud, as Principal Übelschlecht (voice)'],
#  ['Amy Poehler, as Joy (voice)',
#   'Maya Hawke, as Anxiety (voice)',
#   'Kensington Tallman, as Riley (voice)',
#   'Liza Lapira, as Disgust (voice)',
#   'Phyllis Smith, as Sadness (voice)',
#   'Lewis Black, as Anger (voice)',
#   'Tony Hale, as Fear (voice)',
#   'Ayo Edebiri, as Envy (voice)',
#   'Adèle Exarchopoulos, as Ennui (voice)'],
#  ['Will Smith, as Mike Lowrey',
#   'Martin Lawrence, as Marcus Burnett',
#   'Vanessa Hudgens, as Kelly',
#   'Alexander Ludwig, as Dorn',
#   'Paola Nuñez, as Rita',
#   'Eric Dane, as McGrath',
#   'Ioan Gruffudd, as Lockwood',
#   'Jacob Scipio, as Armando',
#   'Melanie Liburd, as Christine'],
#  ['Lakshya Lalwani, as Amrit',
#   'Raghav Juyal, as Fani',
#   'Tanya Maniktala, as Tulika',
#   'Abhishek Chauhan, as Viresh',
#   'Ashish Vidhyarthi, as Beni',
#   'Adrija Sinha, as Aahana',
#   'Harsh Chhaya, as Baldev Singh Thakur',
#   'Parth Tiwari, as Siddhi',
#   'Akshay Vichare, as Ujala'],
#  ["Lupita Nyong'o, as Samira",
#   'Joseph Quinn, as Eric',
#   'Alex Wolff, as Reuben',
#   'Djimon Hounsou, as Henri',
#   'Eliane Umuhire, as Zena',
#   'Takunda Khumalo, as Osahar',
#   'Alfie Todd, as Max',
#   'Avy-Berry Worrall, as Young Sister',
#   'Ronnie Le Drew, as Marvin Monroe'],
#  ['Nassim Lyes, as Sam',
#   'Loryn Nounay, as Mia',
#   'Olivier Gourmet, as Narong',
#   'Vithaya Pansringarm, as Hansa',
#   'Mehdi Hadim,',
#   'Kenneth Won, as Civil Servant',
#   'Sahajak Boonthanakit,',
#   'Chananticha Chaipa, as Dara',
#   'Boonsong Nakphoo,'],
#  ['Cailee Spaeny, as Rain',
#   'David Jonsson, as Andy',
#   'Archie Renaux, as Tyler',
#   'Isabela Merced, as Kay',
#   'Spike Fearn, as Bjorn',
#   'Aileen Wu, as Navarro',
#   'Rosie Ede, as WY Officer',
#   'Soma Simon, as 10-Year-Old Punk #1',
#   'Bence Okeke, as 10-Year-Old Punk #2'],
#  ['Blake Lively, as Lily Bloom',
#   'Justin Baldoni, as Ryle Kincaid',
#   'Brandon Sklenar, as Atlas Corrigan',
#   'Jenny Slate, as Allysa',
#   'Hasan Minhaj, as Marshall',
#   'Amy Morton, as Jenny Bloom',
#   'Kevin McKidd, as Andrew Bloom',
#   'Isabela Ferrer, as Young Lily Bloom',
#   'Alex Neustaedter, as Young Atlas Corrigan'],
#  ['Ryan Phillippe, as Andrew',
#   'Emile Hirsch, as Grun',
#   'Mena Suvari, as Sue',
#   'Dylan Flashner, as Tyler',
#   'Tristan Thompson, as Max',
#   'Michaela Sasner, as Chrissy',
#   'Jeremy Tardy, as Thabo',
#   'Mohamed Hakeemshady, as Scar',
#   'Alpha Miknas, as Fatigues'],
#  ['Lucía Pérez, as Ping (voice)',
#   'Mario Gas, as Danzi (voice)',
#   'Fernando Castro, as Diao (voice)',
#   'Carlos de Luna, as Wang Chao (voice)',
#   'José Gómez Adán, as Kwan (voice)',
#   'César Díaz Capilla, as Master Lan (voice)',
#   'Isabel Gaudí, as Lao Ma (voice)',
#   'Miquel Rodríguez Ros, as Príncipe (voice)',
#   'Álvaro Navarro, as Cara de rata / Walla #2 (voice)'],
#  ['Carolyn Lawrence, as Sandy / Bottomite Crowd (voice)',
#   'Tom Kenny, as SpongeBob / Gary / Sonny / Various (voice)',
#   'Clancy Brown, as Mr. Krabs / Clyde / Additional Voices (voice)',
#   'Bill Fagerbakke, as Patrick Star / Bottomite #4 / Bottomite Crowd (voice)',
#   'Mr. Lawrence, as Plankton / Fred / Larry / Various (voice)',
#   'Rodger Bumpass, as Squidward Tentacles / Butch / Various (voice)',
#   'Johnny Knoxville, as Randy Cheeks (voice)',
#   'Craig Robinson, as Pa Cheeks (voice)',
#   'Grey DeLisle, as Ma Cheeks / Granny Cheeks / Rowdy Cheeks / Rosie Cheeks '
#   '(voice)'],
#  ['Matt Damon, as Rory',
#   'Casey Affleck, as Cobby',
#   'Hong Chau, as Dr. Donna Rivera',
#   'Michael Stuhlbarg, as Mr. Besegai',
#   'Paul Walter Hauser, as Booch',
#   'Ving Rhames, as Frank Toomey',
#   'Alfred Molina, as Richie Dechico',
#   'Toby Jones, as Alan Flynn',
#   'Jack Harlow, as Scalvo'],
#  ['K.J. Apa, as Wes Neal',
#   'Eric Dane, as Dean Miller',
#   'Maia Reficco, as Camila',
#   'Edward James Olmos, as Abel',
#   'Austin North, as Cody',
#   'Jackson Hurst, as Bobby Tresco',
#   'Adam Thomas Ziemba, as Leo',
#   'Libby Blake, as Nikki',
#   'Kevin Saunders, as Bike Shop Father'],
#  ['Chris Pratt, as Garfield (voice)',
#   'Samuel L. Jackson, as Vic (voice)',
#   'Hannah Waddingham, as Jinx (voice)',
#   'Ving Rhames, as Otto (voice)',
#   'Nicholas Hoult, as Jon (voice)',
#   'Cecily Strong, as Marge Malone (voice)',
#   'Harvey Guillén, as Odie (voice)',
#   'Brett Goldstein, as Roland (voice)',
#   'Bowen Yang, as Nolan (voice)'],
#  ['Anya Taylor-Joy, as Furiosa',
#   'Chris Hemsworth, as Dementus',
#   'Tom Burke, as Praetorian Jack',
#   'Alyla Browne, as Young Furiosa',
#   'George Shevtsov, as The History Man',
#   'Lachy Hulme, as Immortan Joe / Rizzdale Pell',
#   'John Howard, as The People Eater',
#   'Angus Sampson, as Organic Mechanic',
#   'Charlee Fraser, as Mary Jabassa'],
#  ['Owen Teague, as Noa',
#   'Freya Allan, as Nova / Mae',
#   'Kevin Durand, as Proximus Caesar',
#   'Peter Macon, as Raka',
#   'William H. Macy, as Trevathan',
#   'Eka Darville, as Sylva',
#   'Travis Jeffery, as Anaya',
#   'Lydia Peckham, as Soona',
#   'Neil Sandilands, as Koro'],
#  ['Guy Pearce, as Thomas Munro',
#   'Tioreore Ngatai-Melbourne, as Rangimai',
#   'Antonio Te Maioha, as Maianui',
#   'Jacqueline McKenzie, as Charlotte',
#   'Te Kohe Tuhaka, as Captive Warrior',
#   'Lawrence Makoare, as Akatarewa',
#   "Dean O'Gorman, as Kedgley",
#   'Jared Turner, as Castor Samuels',
#   'Kelly Vivian, as Epworth Washerwoman / Epworth Dancer'],
#  ['Chen Bolin, as Chang Po-Chun',
#   'Cecilia Choi, as Shen Shu-Wen',
#   'Kent Tsai, as Kao',
#   'JC Lin, as Wen-Hao',
#   'Frederick Lee, as Uncle Bin',
#   'Kang-Ren Wu, as Chen Hai-Jui',
#   'Ven Kao, as Mr. Hu',
#   'McFly Wu, as Mr. Hou',
#   'Jean Ho, as Ann']]

# %% [markdown]
# #### 5. Write an user defined function that returns a pandas data frame with following data:

# %% [markdown]
# * 5.a. Titles of the movies listed on the page
# * 5.b. User ratings of the movies listed on the page
# * 5.c. Genres of the movies listed on the page
# * 5.d. Cast of the movies listed on the page

# %%
import pandas as pd

def create_movies_dataframe(movies_page_url, headers=None, debug=False):
    """
    Creates a pandas DataFrame from the movies page of a given URL.
    The function utilizes existing functions for fetching titles, ratings, generes and casts
    and returns a DataFrame with the fetched data.
    Args:
        movies_page_url (str): The list of URL of the movies detail pages.
        headers (dict): A dictionary of headers to be used in the request. Defaults to None.
        debug (bool): A flag to enable debug mode. Defaults to False.
        Returns: A DataFrame with Titles, Ratings, Generes and Actors for all the movies in the input list
    """
    # Send a GET request to the movies page
    # Initialize lists to store the data
    titles = []
    user_ratings = []
    genres = []
    actors = []

    # First lets get the soup object for the page
    soup = get_soup_object(movies_page_url, headers)
    if debug: pprint(soup)
    # Second get the titles
    titles = get_movie_titles(soup)
    if debug: pprint(titles)
    
    # Third get the user ratings
    user_ratings = get_user_ratings(soup)
    if debug: pprint(user_ratings)
    # Fourth get the details URL
    details_urls = get_movies_details_url(soup)
    if debug: pprint(details_urls)
    # fifth get the genres
    genres = get_movies_genere(details_urls, debug=debug)
    if debug: pprint(genres)
    # sixth get the casts
    actors = get_movies_cast(details_urls, debug=debug)
    if debug: pprint(actors)
    
    # Create a DataFrame from the lists
    df = pd.DataFrame({
        'Title': titles,
        'User Rating %': user_ratings,
        'Genres': genres,
        'Cast': actors
    })
    
    return df

# %%
df = create_movies_dataframe(URL)
pprint(df.head(5))
# Out:
#                    Title User Rating %  \
# 0   Deadpool & Wolverine            78
# 1               Twisters            71
# 2        Despicable Me 4            73
# 3           Inside Out 2            76
# 4  Bad Boys: Ride or Die            76
#
#                                    Genres  \
# 0       [Action, Comedy, Science Fiction]
# 1    [Action, Adventure, Drama, Thriller]
# 2     [Animation, Family, Comedy, Action]
# 3  [Animation, Family, Adventure, Comedy]
# 4       [Action, Crime, Thriller, Comedy]
#
#                                                 Cast
# 0  [Ryan Reynolds, as Wade Wilson / Deadpool / Ni...
# 1  [Daisy Edgar-Jones, as Kate, Glen Powell, as T...
# 2  [Steve Carell, as Gru (voice), Kristen Wiig, a...
# 3  [Amy Poehler, as Joy (voice), Maya Hawke, as A...
# 4  [Will Smith, as Mike Lowrey, Martin Lawrence, ...

# %%
# Write the Dataframe to a CSV file
df.to_csv('tmdb_movies.stats.csv', encoding='utf-8', index=False)

# %% [markdown]
# #### 6. Scraping the data and combining the dataframes

# %% [markdown]
# ##### 6.a Write a function that scrapes data (mentioned in Q5) from page number 1, 2, 3, 4 and 5 on the URL https://www.themoviedb.org/movie and returns 5 data frames which can be exported to csv file by calling the functions defined in Q3a, Q4c and Q5

# %%
def create_movies_dataframes_all_pages(movies_page_base_url, page_start=1, page_count=5, debug=True):
    """
    Create a list of dataframes for no of pages of movies data represented by page_count, starting from page_start
    Args:
        movies_page_base_url (str): The base URL for the movies page.
        page_start (int, optional): The starting page number. Defaults to 1.
        page_count (int, optional): The number of pages to fetch. Defaults to 5.
        debug (bool, optional): If True, print debug messages. Defaults to True.
        Returns: List of DataFrames for each page.
    """
    df_list = []
    for i in range(page_start, page_count+1, 1):
        movies_page_url = f"{movies_page_base_url}?page={i}"
        if debug: print(f'Generating dataframe for {movies_page_url}')
        df_movie = create_movies_dataframe(movies_page_url, headers=None, debug=debug)
        df_list.append(df_movie)
    return df_list

# %%
page_count = 5
print(f"Scraping and creating data frames for base URL: {URL} for {page_count} pages")
df_list = create_movies_dataframes_all_pages(URL, 1, page_count=page_count, debug=False)
print(f"{len(df_list)} Data Frames acquired")

index = 1
for df in df_list:
    print(f"Writing Data Frame to file DataFrame_{index}.csv")    
    df.to_csv(f'DataFrame_{index}.csv', index=False)    
    index += 1
    
print("Execution Completed...")
# Out:
# Scraping and creating data frames for base URL: https://www.themoviedb.org/movie for 5 pages
# 5 Data Frames acquired
# Writing Data Frame to file DataFrame_1.csv
# Writing Data Frame to file DataFrame_2.csv
# Writing Data Frame to file DataFrame_3.csv
# Writing Data Frame to file DataFrame_4.csv
# Writing Data Frame to file DataFrame_5.csv
# Execution Completed...

# %% [markdown]
# ##### 6.b. Combine the data obtained from dataframes in Q6(a)

# %%
def combine_all_dataframes(df_list):
    """
    This function combines all dataframes in a list into one dataframe.
    Args:
        df_list (List of DataFrame): List of DataFrames to combine
        Retuns: A combined dataset using concat method
    """
    # Concatenate all data frames in the list into a single data frame
    combined_df = pd.concat(df_list, ignore_index=True)
    combined_df.reset_index()
    return combined_df

# %%
combined_df = combine_all_dataframes(df_list)
pprint(combined_df)
# Out:
#                                                 Title User Rating %  \
# 0                                Deadpool & Wolverine            78
# 1                                            Twisters            71
# 2                                     Despicable Me 4            73
# 3                                        Inside Out 2            76
# 4                               Bad Boys: Ride or Die            76
# ..                                                ...           ...
# 95                Spider-Man: Across the Spider-Verse            84
# 96  The Chronicles of Narnia: The Lion, the Witch ...            71
# 97                                        Black Noise            53
# 98                            Spider-Man: No Way Home            80
# 99                                    Double Jeopardy            66
#
#                                              Genres  \
# 0                 [Action, Comedy, Science Fiction]
# 1              [Action, Adventure, Drama, Thriller]
# 2               [Animation, Family, Comedy, Action]
# 3            [Animation, Family, Adventure, Comedy]
# 4                 [Action, Crime, Thriller, Comedy]
# ..                                              ...
# 95  [Animation, Action, Adventure, Science Fiction]
# 96                     [Adventure, Family, Fantasy]
# 97      [Action, Science Fiction, Horror, Thriller]
# 98             [Action, Adventure, Science Fiction]
# 99                       [Drama, Thriller, Mystery]
#
#                                                  Cast
# 0   [Ryan Reynolds, as Wade Wilson / Deadpool / Ni...
# 1   [Daisy Edgar-Jones, as Kate, Glen Powell, as T...
# 2   [Steve Carell, as Gru (voice), Kristen Wiig, a...
# 3   [Amy Poehler, as Joy (voice), Maya Hawke, as A...
# 4   [Will Smith, as Mike Lowrey, Martin Lawrence, ...
# ..                                                ...
# 95  [Shameik Moore, as Miles Morales (voice), Hail...
# 96  [Georgie Henley, as Lucy Pevensie, Skandar Key...
# 97  [Jackson Rathbone, as Leo, Alex Pettyfer,, Eve...
# 98  [Tom Holland, as Peter Parker / Spider-Man, Ze...
# 99  [Ashley Judd, as Libby Parsons, Tommy Lee Jone...
#
# [100 rows x 4 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          100 non-null    object
#  1   User Rating %  100 non-null    object
#  2   Genres         100 non-null    object
#  3   Cast           100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %%
combined_df.describe()
# Out:
#                        Title User Rating %              Genres  \
# count                    100           100                 100
# unique                   100            37                  76
# top     Deadpool & Wolverine            70  [Horror, Thriller]
# freq                       1             8                   5
#
#                                                      Cast
# count                                                 100
# unique                                                100
# top     [Ryan Reynolds, as Wade Wilson / Deadpool / Ni...
# freq                                                    1

# %%
combined_df.to_csv('TMDB_DataFrme_Combined.csv', index=False)
